# %%
import pandas as pd
import json
import numpy as np
from globals import BASE_DIR
import os
import matplotlib.pyplot as plt
import random
from evaluation_metrics import *


top_k_resample = 150
top_k_eval = 10
gridsearch = True
save_upd = True
use_subsample = True

general_models = ["BPR"]
context_models = ["LORE", "USG"]
context_models = []

available_datasets = ["brightkite", "foursquaretky", "gowalla", "snowcard", "yelp"]
available_datasets = ["snowcard", "yelp"]


#valid_popularity = "business_popularity:float"
valid_popularity = "item_pop"

recommendation_dirpart = "recommendations"

pd.options.mode.copy_on_write = True

# %%
# Define the datasets you want to process
def dataset_metadata(dataset, recommendation_dirpart=recommendation_dirpart):
    data = []

    recs = os.listdir(f"{BASE_DIR}{dataset}_dataset/{recommendation_dirpart}")
    if '.DS_Store' in recs:
        recs.remove('.DS_Store')

    for dir in recs:
        json_file = f"{BASE_DIR}{dataset}_dataset/{recommendation_dirpart}/{dir}/general_evaluation.json"
        
        with open(json_file, 'r') as f:
            eval_data = json.load(f)
        
        # Extract the test_result data and flatten it
        test_results = eval_data.get("test_result", {})
        test_results["directory"] = dir

        test_results["dataset"] = test_results["directory"].split("-")[0]
        test_results["model"] = test_results["directory"].split("-")
        if test_results["directory"].split("-")[1] == "debias":
            test_results["model_type"] = "debias"
            test_results["date"] = "-".join(test_results["directory"].split("-")[3:])
        
        elif test_results["directory"].split("-")[1] == "contextpoi":
            test_results["model_type"] = "contextpoi"
            test_results["date"] = "-".join(test_results["directory"].split("-")[3:])
        else:
            test_results["model_type"] = "general"
            test_results["date"] = "-".join(test_results["directory"].split("-")[2:])

        if test_results["model_type"] == "debias":
            test_results["model"] = test_results["model"][2]
        
        elif test_results["model_type"] == "contextpoi":
            test_results["model"] = test_results["model"][2]
            
        else:
            test_results["model"] = test_results["model"][1]

        if test_results["model"] == "MF":
            test_results["model_type"] = "general (via RecBole debias)"

        test_results["dataset"] = test_results["dataset"].split("_")[0]
        if test_results["model_type"] != "debias":
            data.append(test_results)

    return data

# %%
def unstack_recommendations(df):
    # Repeat each user_id for the length of their item_id:token list
    unstacked_df = df.explode(["item_id:token", "score"]).reset_index(drop=True)
    return unstacked_df

# %%
def create_base_recommendations(recommender_dir, top_k_resample=top_k_resample, top_k_eval=top_k_eval):

    with open(recommender_dir) as f:
        data = json.load(f)


    base_recommendations = []

    for user, items in data.items():
        for item in items:
            base_recommendations.append({
                "user_id:token": user,
                "item_id:token": item["item_id"],
                "score": item["score"]
            })

    base_df = pd.DataFrame(base_recommendations)
    base_df = unstack_recommendations(base_df)

    # normalize the scores
    base_df["score"] = base_df.groupby("user_id:token")["score"].transform(lambda x: (x - x.min()) / (x.max() - x.min()))


    # top k recommendations for resampling
    base_top_k_df = (
        base_df.groupby("user_id:token")
        .head(top_k_resample)
        .reset_index(drop=True)
    )

    # top k recommendations for evaluation
    base_eval_df = (
        base_df.groupby("user_id:token")
        .head(top_k_eval)
        .reset_index(drop=True)
    )

    return base_top_k_df, base_eval_df

# %%
def save_top_k(sorted_top_k_df, base_dir, reranking_method):
    # Create the directory if it doesn't exist
    grouped_data = (
        sorted_top_k_df.groupby("user_id:token")["item_id:token"]
        .apply(list)
        .to_dict()
    )


    save_path = os.path.join(base_dir, reranking_method)
    os.makedirs(save_path, exist_ok=True)
    file_path = os.path.join(save_path, "top_k_recommendations.json")

    with open(file_path, "w") as f:
        json.dump(grouped_data, f, indent=4)

    print(f"Saved recommendations to {file_path}")

# %%
def save_cp_metadata(base_dir, file, filename):
    # Create the directory if it doesn't exist
    
    save_path = os.path.join(base_dir, "cp")
    os.makedirs(save_path, exist_ok=True)
    file_path = os.path.join(save_path, f"{filename}.json")

    with open(file_path, "w") as f:
        json.dump(file, f, indent=4)

    print(f"Saved recommendations to {file_path}")

# %%
def rerank_upd(dataset, base_df, top_k_eval, valid_popularity, dir_to_save, calibrate_on="mean"):
    # Load user-item interaction data
    checkin_df = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/processed_data_recbole/{dataset}_sample.inter", sep="\t")
    
    # Calculate item popularity
    value_counts = checkin_df["item_id:token"].value_counts().reset_index()
    value_counts.columns = ["item_id:token", "count"]
    value_counts[valid_popularity] = value_counts["count"] / len(value_counts)
    checkin_df = checkin_df.merge(value_counts[["item_id:token", valid_popularity]], on="item_id:token", how="left")

    # Assign item popularity groups
    checkin_df.sort_values(by=valid_popularity, ascending=False, inplace=True)
    item_popularity = checkin_df.drop_duplicates(subset="item_id:token", keep="first")[["item_id:token", valid_popularity]]
    
    h_group = item_popularity.head(int(len(item_popularity) * 0.2))
    h_group["item_pop_group"] = "h"
    t_group = item_popularity.tail(int(len(item_popularity) * 0.2))
    t_group["item_pop_group"] = "t"
    m_group = item_popularity[
        ~item_popularity["item_id:token"].isin(h_group["item_id:token"]) &
        ~item_popularity["item_id:token"].isin(t_group["item_id:token"])
    ]
    m_group["item_pop_group"] = "m"

    item_popularity = pd.concat([h_group, m_group, t_group])
    item_popularity.sort_values(by=valid_popularity, inplace=True, ascending=False)

    checkin_df = checkin_df.merge(item_popularity[["item_id:token", "item_pop_group"]], on="item_id:token", how="left")

    # Calculate user popularity tolerance score (UPTS)
    if calibrate_on == "mean":
        upts = checkin_df.groupby("user_id:token")[valid_popularity].mean().reset_index()
    else:
        upts = checkin_df.groupby("user_id:token")[valid_popularity].median().reset_index()

    upts.columns = ["user_id:token", "upts"]

    # Merge and calculate UPD
    merged_df = base_df.merge(upts, on="user_id:token").merge(item_popularity, on="item_id:token")
    merged_df["upd"] = (merged_df[valid_popularity] - merged_df["upts"]).abs()

    # Extract calibrated top-k recommendations
    sorted_top_k_df = (
        merged_df.sort_values(by=["user_id:token", "upd"], ascending=True)
        .groupby("user_id:token")
        .head(top_k_eval)
        .reset_index(drop=True)
    )

    return sorted_top_k_df, item_popularity, upts

# %% [markdown]
# ## Implement CP from here:
#
# https://github.com/rUngruh/mitigatingPopularityBiasInMRS/blob/main/studytool/Tool-Module/scripts/LFMRecommendations/Models/mitigation.py

# %%
def open_ground_truth_user_group(dataset):
    # Stays the same across all models 
    train_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/processed_data_recbole/{dataset}_sample.train.inter", sep="\t")
    test_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/processed_data_recbole/{dataset}_sample.test.inter", sep="\t")
    valid_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/processed_data_recbole/{dataset}_sample.valid.inter", sep="\t")
    #valid_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/processed_data_recbole/{dataset}_sample.valid.inter", sep="\t") # originale struktur !!!
    train_data = pd.concat([train_data, valid_data])
    user_group_dir = f"{BASE_DIR}{dataset}_dataset/{dataset}_user_id_popularity.json"
    with open(user_group_dir) as f:
        user_groups = json.load(f)

    return train_data, test_data, user_groups

# %%
def recommender_dir_combiner(dataset, modelpart):
    top_k_dir = f"{BASE_DIR}{dataset}_dataset/{recommendation_dirpart}/{modelpart}/top_k_recommendations.json"
    recommendation_folder = f"{BASE_DIR}{dataset}_dataset/{recommendation_dirpart}/{modelpart}"
    return top_k_dir, recommendation_folder

# %%
def calculate_user_popularity_distributions(df, item_popularity):

    #df = df.merge(item_popularity, on="item_id:token", how="left")
    # Calculate mean, median, and variance of `business_popularity` for each user
    user_stats = df.groupby('user_id:token')[valid_popularity].agg(['mean', 'median', 'var']).reset_index()

    # Calculate normalized ratios of `item_pop_group` for each user
    pop_group_counts = df.groupby(['user_id:token', 'item_pop_group']).size().unstack(fill_value=0)

    # Normalize by row sum to get ratios
    pop_group_ratios = pop_group_counts.div(pop_group_counts.sum(axis=1), axis=0).reset_index()

    # Merge the statistics and ratios into a single DataFrame
    user_pop_ratio_df = pd.merge(user_stats, pop_group_ratios, on='user_id:token', how='left')

    # Rename columns for clarity
    user_pop_ratio_df.rename(columns={'h': 'h_ratio', 'm': 'm_ratio', 't': 't_ratio', 'mean' : 'mean_pop', 'median' : 'median_pop', 'var' : 'variance_pop'}, inplace=True)

    num_interactions = df.groupby('user_id:token').size().reset_index(name='num_interactions')

    # Merge the num_interactions into the user_pop_ratio_df
    user_pop_ratio_df = pd.merge(user_pop_ratio_df, num_interactions, on='user_id:token', how='left')

    return user_pop_ratio_df

# %%
def get_profile_and_recommended_ratios_for_js(test_item_groups, test_user_profile):
    recommended_ratios_nested = test_item_groups.to_dict()
    recommended_ratios = {key: list(value.values())[0] for key, value in recommended_ratios_nested.items()}

    # Extract user profile ratios
    profile_ratios = {
        'h_ratio': test_user_profile['h_ratio'].iloc[0],
        'm_ratio': test_user_profile['m_ratio'].iloc[0],
        't_ratio': test_user_profile['t_ratio'].iloc[0],
    }

    return recommended_ratios, profile_ratios


def rerank_for_user(initial_list, scores, item_popularity, user_profile, delta, k, user_id):
    """
    Perform the re-ranking for a single user using the CP algorithm.
    """
    reranked_list = []
    category_counts = {'h': 0, 'm': 0, 't': 0}  # Initialize category counts
    score_count = 0  # Tracks cumulative score

    # Iteratively build the re-ranked list for the user
    for i in range(k):
        # Calculate marginal relevance for all items for the current user
        criterion = marginal_relevances(
            score_count, scores, item_popularity, category_counts, len(reranked_list), user_profile, delta)
        
        # Exclude zero values from the criterion
        non_zero_indices = [idx for idx, value in enumerate(criterion) if value != 0]
        
        if non_zero_indices:
            # Extract the non-zero values
            non_zero_values = [criterion[idx] for idx in non_zero_indices]
            
            if all(value < 0 for value in non_zero_values):  # All remaining values are negative
                # Choose the value closest to zero
                closest_to_zero_value = min(non_zero_values, key=lambda x: abs(x))
                selected_idx = non_zero_indices[non_zero_values.index(closest_to_zero_value)]
            else:
                # Choose the maximum value (default behavior)
                selected_idx = non_zero_indices[np.argmax(non_zero_values)]
        else:
            # Fallback: All values are zero
            selected_idx = np.argmax(criterion)  # Default to the first max zero


        # Update score and add selected item to re-ranked list
        score_count += scores[selected_idx]
        reranked_list.append(initial_list[selected_idx])
       
        # Update category counts
        category_counts[item_popularity[selected_idx]] += 1

        # Remove selected item from the lists
        del initial_list[selected_idx]
        del scores[selected_idx]
        del item_popularity[selected_idx]

    return reranked_list


def marginal_relevances(score_count, item_scores, item_popularities, category_counts, list_len, user_profile, delta):
    """
    Computes the marginal relevance, the criterion for CP
    """
    relevances = np.zeros(len(item_scores))
    recommendation_counts = pd.DataFrame({'h_ratio': [category_counts['h']],
                                           'm_ratio': [category_counts['m']],
                                           't_ratio': [category_counts['t']]})
    computed_categories = set()

    for i, (score, popularity) in enumerate(zip(item_scores, item_popularities)):
        
        if popularity in computed_categories:
            continue  # Avoid duplicate calculations for the same popularity class

        #print(f"Item {i}: score={score}, popularity={popularity}")
        computed_categories.add(popularity)

        # Increment the count temporarily
        recommendation_counts[popularity + '_ratio'] += 1
        recommendation_ratios = recommendation_counts / (list_len + 1)  # Normalize counts

        #print(f"Iteration {list_len + 1}: Temporary recommendation ratios: {recommendation_ratios}")

        # Compute marginal relevance with adjusted formula
        rec_ratios, profile_ratios = get_profile_and_recommended_ratios_for_js(recommendation_ratios, user_profile)
        js_divergence = jensen_shannon(profile_ratios, rec_ratios)
        
        relevances[i] = (1 - delta) * (score_count + score) - delta * js_divergence

        recommendation_counts[popularity + '_ratio'] -= 1
    return relevances



def get_individual_user_data(df, user_profiles, user_id):
    test_user_id = user_id
    test_recs = df.loc[df["user_id:token"] == test_user_id]["item_id:token"].values.tolist()   
    test_scores = df.loc[df["user_id:token"] == test_user_id]["score"].values.tolist()
    test_item_pops = df.loc[df["user_id:token"] == test_user_id][valid_popularity].values.tolist()
    test_item_groups = df.loc[df["user_id:token"] == test_user_id]["item_pop_group"].values.tolist()
    test_user_profile = user_profiles.loc[user_profiles["user_id:token"] == test_user_id]
    return test_scores, test_recs, test_item_pops, test_item_groups, test_user_id, test_user_profile


def rerank_cp_all_users(df, user_profiles, top_k_eval, delta):
    reranked_results = {}
    
    for i, user_id in enumerate(df['user_id:token'].unique()):
        test_scores, test_recs, test_item_pops, test_item_groups, test_user_id, test_user_profile = get_individual_user_data(df, user_profiles, user_id)
        reranked_list = rerank_for_user(test_recs, test_scores, test_item_groups, test_user_profile, delta, top_k_eval, test_user_id)
        reranked_results[test_user_id] = reranked_list
    
        

    # Create the DataFrame **after** the loop
    cp_results = pd.DataFrame([reranked_results]).T.reset_index()
    cp_results.columns = ["user_id:token", "item_id:token"]
    cp_reranked_df = cp_results.explode('item_id:token').reset_index(drop=True)
    
    return cp_reranked_df

# %%
def sample_user_groups(user_groups, sample_size=100):
    sampled_groups = {}
    for group, ids in user_groups.items():
        if len(ids) >= sample_size:
            sampled_groups[group] = random.sample(ids, sample_size)
        else:
            print(f"Warning: Group '{group}' has less than {sample_size} users. Sampling all users.")
            sampled_groups[group] = ids
    return sampled_groups

# %%
def calculate_group_ratios(user_groups, df):
    """Use for plotting"""
    group_results = {}

    for group_name, user_ids in user_groups.items():

        # Filter reranked_df_user and user_profiles for the current user group
        reranked_group_df = df.loc[df['user_id:token'].isin(user_ids)]

        # Calculate means for each ratio

        # if 't_ratio' not in reranked_group_df.columns:
        #     reranked_group_df['t_ratio'] = 0  # or some other default value

        means = reranked_group_df[['h_ratio', 'm_ratio', 't_ratio']].mean().to_dict()

        # Save results
        group_results[group_name] = means

    return group_results

# %%
def get_extreme(results, metric, mode='max', use_abs=False):

    """
    Finds the delta that gives the extreme value (argmax or argmin) for a given metric across all groups.
    
    Parameters:
    - results (dict): The nested results dictionary.
    - metric (str): The metric to compute the extreme for (e.g., 'ndcg', 'arp', 'poplift', 'js_divergence').
    - mode (str): Either 'max' (default) or 'min' to compute the argmax or argmin.
    - use_abs (bool): Whether to compute extremes based on the absolute value of the metric.
    
    Returns:
    - dict: A dictionary with group names as keys and the corresponding delta and extreme value.
    """
    if mode not in ['max', 'min']:
        raise ValueError("Mode must be either 'max' or 'min'.")
    
    extreme_dict = {}
    compare = max if mode == 'max' else min
    extreme_value_init = float('-inf') if mode == 'max' else float('inf')
    
    for group_name in next(iter(results.values())).keys():  # Get group names from the first delta
        extreme_value = extreme_value_init
        best_delta = None
        
        for delta, group_data in results.items():
            if metric in group_data[group_name]:  # Check if the metric exists
                value = abs(group_data[group_name][metric]) if use_abs else group_data[group_name][metric]
                if compare(value, extreme_value) == value:
                    extreme_value = value
                    best_delta = delta
        
        extreme_dict[group_name] = best_delta
    
    return extreme_dict

# %%
def cp_gridsearch(base_resample, user_profiles, top_k_eval, item_popularity, train_data, test_data, user_groups, upts, recommendation_folder):
    deltas = [0, 0.1, 0.3, 0.5, 0.7, 0.9, 1]
    results = {}
    gridsearch_best_deltas = {}
    for i, delta in enumerate(deltas):
        results[delta] = {}
        reranked_df = rerank_cp_all_users(base_resample, user_profiles, top_k_eval, delta=delta)
        reranked_df = reranked_df.merge(item_popularity, on="item_id:token")
        base_arp_scores, base_poplift_scores, calibrated_arp_scores, calibrated_poplift_scores, base_ndcg_scores, calibrated_ndcg_scores = calculate_deltas(test_data, base_resample, reranked_df, item_popularity, upts, valid_popularity, top_k_eval)
        reranked_df_user = calculate_user_popularity_distributions(reranked_df, item_popularity)
        user_profiles = calculate_user_popularity_distributions(train_data, item_popularity)

        group_hmt_means_up = calculate_group_ratios(user_groups, user_profiles)
        group_hmt_means_reranked = calculate_group_ratios(user_groups, reranked_df_user)


        group_means = evaluation_user_group_means(calibrated_ndcg_scores, calibrated_arp_scores, calibrated_poplift_scores, user_groups)
        for group_name, user_ids in user_groups.items():
            # Filter reranked_df_user and user_profiles for the current user group
            #reranked_group_df = reranked_df_user.loc[reranked_df_user['user_id:token'].isin(user_ids)]
            #user_profile_group_df = user_profiles.loc[user_profiles['user_id:token'].isin(user_ids)]
            js = jensen_shannon(group_hmt_means_up[group_name], group_hmt_means_reranked[group_name])
            harmonic_mean = group_means[group_name]['ndcg_mean'] * (1 - js) / (group_means[group_name]['ndcg_mean'] + (1 - js))

            results[delta][group_name] = {
                "js_divergence": js,
                "harmonic_mean": harmonic_mean,
                "ndcg":  group_means[group_name]['ndcg_mean'],
                "arp": group_means[group_name]['arp_mean'],
                "poplift": group_means[group_name]['poplift_mean']
            }

    gridsearch_best_deltas["ndcg"] = get_extreme(results, 'ndcg')
    gridsearch_best_deltas["arp"] = get_extreme(results, 'arp', mode='min')
    gridsearch_best_deltas["harmonic_mean"] = get_extreme(results, 'harmonic_mean')
    gridsearch_best_deltas["js"] = get_extreme(results, 'js_divergence', mode='min')
    gridsearch_best_deltas["poplift"] = get_extreme(results, 'poplift', mode='min', use_abs=True)

    save_cp_metadata(recommendation_folder, gridsearch_best_deltas, "gridsearch_best_deltas")
    save_cp_metadata(recommendation_folder, results, "gridsearch_results")

    return gridsearch_best_deltas

# %%
for dataset in available_datasets:
    data = dataset_metadata(dataset)
    for result in data:
        try:
            print(f"Processing model {result['model']} on dataset {result['dataset']}")
            baseline_topk_dir, basedir = recommender_dir_combiner(dataset, result["directory"])
            train_data, test_data, user_groups = open_ground_truth_user_group(dataset)
            base_resample, base_eval = create_base_recommendations(baseline_topk_dir, top_k_resample=top_k_resample, top_k_eval=top_k_eval)

            upd_eval, item_popularity, upts = rerank_upd(
                dataset, base_resample, top_k_eval, valid_popularity, dir_to_save=basedir, calibrate_on="mean")

            if save_upd:
                save_top_k(upd_eval, basedir, "upd")

            ##### Using a smaller subsample for testing deltas in cp
            user_groups = sample_user_groups(user_groups, sample_size=50) # for testing
            sampled_user_ids = set(id_ for group in user_groups.values() for id_ in group) # for testing
            dataframes_to_filter = [train_data, test_data, base_resample, base_eval, upts] # for testing
            filtered_dataframes = [df.loc[df['user_id:token'].isin(sampled_user_ids)] for df in dataframes_to_filter] # for testing
            train_data, test_data, base_resample, base_eval, upts = filtered_dataframes # for testing
            #### End of using a smaller subsample for testing deltas in cp

            all_user_ids = set(user_groups['high']) | set(user_groups['medium']) | set(user_groups['low'])
            user_groups['all'] = list(all_user_ids)



            base_resample = base_resample.merge(item_popularity, on="item_id:token")
            test_data = test_data.merge(item_popularity, on="item_id:token", how="left")
            train_data = train_data.merge(item_popularity, on="item_id:token", how="left")
            user_profiles = calculate_user_popularity_distributions(train_data, item_popularity)


            if gridsearch:
                cp_gridsearch_best_deltas = cp_gridsearch(base_resample, user_profiles, top_k_eval,item_popularity, train_data, test_data, user_groups, upts, basedir)

            else:
                cp_gridsearch_best_deltas = json.load(open(f"{basedir}/cp/gridsearch_best_deltas.json"))
        except Exception as e:
            print(f"Error processing model {result['model']} on dataset {result['dataset']}: {e}")
            continue
# Out:
# Processing model BPR on dataset brightkite
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_group["item_pop_group"] = "h"
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_group["item_pop_group"] = "t"
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_group["item_pop_group"] = "m"
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/brightkite_dataset/recommendations/brightkite_sample-BPR-Oct-26-2024_15-21-48/upd/top_k_recommendations.json
# Group: high - nDCG: 0.03463; ARP: 0.02313; Poplift: -0.54128
# Group: medium - nDCG: 0.01463; ARP: 0.02356; Poplift: -0.43429
# Group: low - nDCG: 0.04036; ARP: 0.02320; Poplift: -0.27420
# Group: all - nDCG: 0.02987; ARP: 0.02330; Poplift: -0.41659
# **************************************************
# Group: high - nDCG: 0.03463; ARP: 0.02331; Poplift: -0.53749
# Group: medium - nDCG: 0.01492; ARP: 0.02358; Poplift: -0.43358
# Group: low - nDCG: 0.04036; ARP: 0.02320; Poplift: -0.27446
# Group: all - nDCG: 0.02997; ARP: 0.02336; Poplift: -0.41517
# **************************************************
# Group: high - nDCG: 0.03463; ARP: 0.02343; Poplift: -0.53465
# Group: medium - nDCG: 0.02070; ARP: 0.02386; Poplift: -0.42730
# Group: low - nDCG: 0.03974; ARP: 0.02341; Poplift: -0.26821
# Group: all - nDCG: 0.03169; ARP: 0.02356; Poplift: -0.41005
# **************************************************
# Group: high - nDCG: 0.03301; ARP: 0.02394; Poplift: -0.52343
# Group: medium - nDCG: 0.02094; ARP: 0.02432; Poplift: -0.41562
# Group: low - nDCG: 0.03974; ARP: 0.02342; Poplift: -0.26785
# Group: all - nDCG: 0.03123; ARP: 0.02389; Poplift: -0.40230
# **************************************************
# Group: high - nDCG: 0.03162; ARP: 0.02449; Poplift: -0.51206
# Group: medium - nDCG: 0.02286; ARP: 0.02520; Poplift: -0.39531
# Group: low - nDCG: 0.04343; ARP: 0.02379; Poplift: -0.25902
# Group: all - nDCG: 0.03264; ARP: 0.02450; Poplift: -0.38879
# **************************************************
# Group: high - nDCG: 0.02987; ARP: 0.02648; Poplift: -0.47275
# Group: medium - nDCG: 0.02307; ARP: 0.02786; Poplift: -0.33430
# Group: low - nDCG: 0.04379; ARP: 0.02431; Poplift: -0.24429
# Group: all - nDCG: 0.03224; ARP: 0.02621; Poplift: -0.35045
# **************************************************
# Group: high - nDCG: 0.03557; ARP: 0.02884; Poplift: -0.42370
# Group: medium - nDCG: 0.03110; ARP: 0.03018; Poplift: -0.28044
# Group: low - nDCG: 0.04440; ARP: 0.02532; Poplift: -0.21061
# Group: all - nDCG: 0.03702; ARP: 0.02811; Poplift: -0.30492
# **************************************************
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/brightkite_dataset/recommendations/brightkite_sample-BPR-Oct-26-2024_15-21-48/cp/gridsearch_best_deltas.json
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/brightkite_dataset/recommendations/brightkite_sample-BPR-Oct-26-2024_15-21-48/cp/gridsearch_results.json
# Processing model LORE on dataset brightkite
# Error processing model LORE on dataset brightkite: 'score'
# Processing model USG on dataset brightkite
# Error processing model USG on dataset brightkite: 'score'
# Processing model SimpleX on dataset brightkite
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_group["item_pop_group"] = "h"
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_group["item_pop_group"] = "t"
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_group["item_pop_group"] = "m"
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/brightkite_dataset/recommendations/brightkite_sample-SimpleX-Oct-26-2024_18-51-25/upd/top_k_recommendations.json
# Group: high - nDCG: 0.07314; ARP: 0.02398; Poplift: -0.53704
# Group: medium - nDCG: 0.01291; ARP: 0.02286; Poplift: -0.45977
# Group: low - nDCG: 0.03394; ARP: 0.02340; Poplift: -0.25415
# Group: all - nDCG: 0.04000; ARP: 0.02341; Poplift: -0.41699
# **************************************************
# Group: high - nDCG: 0.07638; ARP: 0.02395; Poplift: -0.53768
# Group: medium - nDCG: 0.01291; ARP: 0.02308; Poplift: -0.45465
# Group: low - nDCG: 0.03394; ARP: 0.02344; Poplift: -0.25352
# Group: all - nDCG: 0.04107; ARP: 0.02349; Poplift: -0.41529
# **************************************************
# Group: high - nDCG: 0.07725; ARP: 0.02427; Poplift: -0.53187
# Group: medium - nDCG: 0.01291; ARP: 0.02306; Poplift: -0.45482
# Group: low - nDCG: 0.03972; ARP: 0.02340; Poplift: -0.25364
# Group: all - nDCG: 0.04329; ARP: 0.02358; Poplift: -0.41344
# **************************************************
# Group: high - nDCG: 0.08126; ARP: 0.02499; Poplift: -0.51912
# Group: medium - nDCG: 0.01245; ARP: 0.02368; Poplift: -0.44099
# Group: low - nDCG: 0.04149; ARP: 0.02357; Poplift: -0.24708
# Group: all - nDCG: 0.04506; ARP: 0.02408; Poplift: -0.40240
# **************************************************
# Group: high - nDCG: 0.08102; ARP: 0.02601; Poplift: -0.50085
# Group: medium - nDCG: 0.01811; ARP: 0.02440; Poplift: -0.42524
# Group: low - nDCG: 0.04319; ARP: 0.02420; Poplift: -0.22535
# Group: all - nDCG: 0.04744; ARP: 0.02487; Poplift: -0.38382
# **************************************************
# Group: high - nDCG: 0.07524; ARP: 0.02751; Poplift: -0.46837
# Group: medium - nDCG: 0.01492; ARP: 0.02647; Poplift: -0.37855
# Group: low - nDCG: 0.03209; ARP: 0.02485; Poplift: -0.20496
# Group: all - nDCG: 0.04075; ARP: 0.02628; Poplift: -0.35063
# **************************************************
# Group: high - nDCG: 0.08102; ARP: 0.03001; Poplift: -0.41955
# Group: medium - nDCG: 0.01600; ARP: 0.02830; Poplift: -0.33581
# Group: low - nDCG: 0.03409; ARP: 0.02589; Poplift: -0.17668
# Group: all - nDCG: 0.04370; ARP: 0.02807; Poplift: -0.31068
# **************************************************
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/brightkite_dataset/recommendations/brightkite_sample-SimpleX-Oct-26-2024_18-51-25/cp/gridsearch_best_deltas.json
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/brightkite_dataset/recommendations/brightkite_sample-SimpleX-Oct-26-2024_18-51-25/cp/gridsearch_results.json
# Processing model BPR on dataset foursquaretky
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_group["item_pop_group"] = "h"
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_group["item_pop_group"] = "t"
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_group["item_pop_group"] = "m"
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/foursquaretky_dataset/recommendations/foursquaretky_sample-BPR-Oct-26-2024_15-27-44/upd/top_k_recommendations.json
# Group: high - nDCG: 0.04847; ARP: 0.01892; Poplift: -0.43295
# Group: medium - nDCG: 0.01298; ARP: 0.01906; Poplift: -0.30344
# Group: low - nDCG: 0.01000; ARP: 0.01871; Poplift: -0.27114
# Group: all - nDCG: 0.02381; ARP: 0.01890; Poplift: -0.33585
# **************************************************
# Group: high - nDCG: 0.04818; ARP: 0.01876; Poplift: -0.43767
# Group: medium - nDCG: 0.01298; ARP: 0.01868; Poplift: -0.32109
# Group: low - nDCG: 0.01000; ARP: 0.01869; Poplift: -0.27175
# Group: all - nDCG: 0.02372; ARP: 0.01871; Poplift: -0.34350
# **************************************************
# Group: high - nDCG: 0.04794; ARP: 0.01884; Poplift: -0.43574
# Group: medium - nDCG: 0.01343; ARP: 0.01856; Poplift: -0.32540
# Group: low - nDCG: 0.01000; ARP: 0.01833; Poplift: -0.28124
# Group: all - nDCG: 0.02379; ARP: 0.01858; Poplift: -0.34746
# **************************************************
# Group: high - nDCG: 0.05332; ARP: 0.01785; Poplift: -0.46578
# Group: medium - nDCG: 0.01343; ARP: 0.01806; Poplift: -0.34204
# Group: low - nDCG: 0.01262; ARP: 0.01797; Poplift: -0.29579
# Group: all - nDCG: 0.02646; ARP: 0.01796; Poplift: -0.36787
# **************************************************
# Group: high - nDCG: 0.04708; ARP: 0.01706; Poplift: -0.48197
# Group: medium - nDCG: 0.01291; ARP: 0.01744; Poplift: -0.36469
# Group: low - nDCG: 0.01262; ARP: 0.01681; Poplift: -0.33645
# Group: all - nDCG: 0.02420; ARP: 0.01710; Poplift: -0.39437
# **************************************************
# Group: high - nDCG: 0.03528; ARP: 0.01624; Poplift: -0.50419
# Group: medium - nDCG: 0.00667; ARP: 0.01523; Poplift: -0.46274
# Group: low - nDCG: 0.01262; ARP: 0.01400; Poplift: -0.44422
# Group: all - nDCG: 0.01819; ARP: 0.01516; Poplift: -0.47038
# **************************************************
# Group: high - nDCG: 0.04761; ARP: 0.01490; Poplift: -0.55209
# Group: medium - nDCG: 0.01245; ARP: 0.01264; Poplift: -0.56625
# Group: low - nDCG: 0.02000; ARP: 0.01250; Poplift: -0.50394
# Group: all - nDCG: 0.02669; ARP: 0.01334; Poplift: -0.54076
# **************************************************
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/foursquaretky_dataset/recommendations/foursquaretky_sample-BPR-Oct-26-2024_15-27-44/cp/gridsearch_best_deltas.json
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/foursquaretky_dataset/recommendations/foursquaretky_sample-BPR-Oct-26-2024_15-27-44/cp/gridsearch_results.json
# Processing model LORE on dataset foursquaretky
# Error processing model LORE on dataset foursquaretky: 'score'
# Processing model USG on dataset foursquaretky
# Error processing model USG on dataset foursquaretky: 'score'
# Processing model SimpleX on dataset foursquaretky
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_group["item_pop_group"] = "h"
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_group["item_pop_group"] = "t"
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_group["item_pop_group"] = "m"
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/foursquaretky_dataset/recommendations/foursquaretky_sample-SimpleX-Oct-26-2024_18-59-33/upd/top_k_recommendations.json
# Group: high - nDCG: 0.03774; ARP: 0.01983; Poplift: -0.39244
# Group: medium - nDCG: 0.02602; ARP: 0.02002; Poplift: -0.33144
# Group: low - nDCG: 0.00000; ARP: 0.01978; Poplift: -0.29810
# Group: all - nDCG: 0.02125; ARP: 0.01987; Poplift: -0.34066
# **************************************************
# Group: high - nDCG: 0.03774; ARP: 0.01964; Poplift: -0.40122
# Group: medium - nDCG: 0.02602; ARP: 0.02002; Poplift: -0.33144
# Group: low - nDCG: 0.00000; ARP: 0.01972; Poplift: -0.29915
# Group: all - nDCG: 0.02125; ARP: 0.01979; Poplift: -0.34394
# **************************************************
# Group: high - nDCG: 0.03036; ARP: 0.01955; Poplift: -0.40350
# Group: medium - nDCG: 0.02602; ARP: 0.01926; Poplift: -0.34515
# Group: low - nDCG: 0.00000; ARP: 0.01944; Poplift: -0.30716
# Group: all - nDCG: 0.01879; ARP: 0.01942; Poplift: -0.35193
# **************************************************
# Group: high - nDCG: 0.04066; ARP: 0.01941; Poplift: -0.40667
# Group: medium - nDCG: 0.02631; ARP: 0.01885; Poplift: -0.36891
# Group: low - nDCG: 0.00000; ARP: 0.01849; Poplift: -0.33790
# Group: all - nDCG: 0.02232; ARP: 0.01892; Poplift: -0.37116
# **************************************************
# Group: high - nDCG: 0.04119; ARP: 0.01888; Poplift: -0.42244
# Group: medium - nDCG: 0.03758; ARP: 0.01834; Poplift: -0.38490
# Group: low - nDCG: 0.00000; ARP: 0.01719; Poplift: -0.38215
# Group: all - nDCG: 0.02626; ARP: 0.01814; Poplift: -0.39650
# **************************************************
# Group: high - nDCG: 0.04824; ARP: 0.01630; Poplift: -0.48910
# Group: medium - nDCG: 0.03900; ARP: 0.01680; Poplift: -0.43022
# Group: low - nDCG: 0.00000; ARP: 0.01488; Poplift: -0.46762
# Group: all - nDCG: 0.02908; ARP: 0.01599; Poplift: -0.46231
# **************************************************
# Group: high - nDCG: 0.04431; ARP: 0.01325; Poplift: -0.60921
# Group: medium - nDCG: 0.03964; ARP: 0.01371; Poplift: -0.52071
# Group: low - nDCG: 0.00000; ARP: 0.01170; Poplift: -0.60288
# Group: all - nDCG: 0.02798; ARP: 0.01289; Poplift: -0.57760
# **************************************************
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/foursquaretky_dataset/recommendations/foursquaretky_sample-SimpleX-Oct-26-2024_18-59-33/cp/gridsearch_best_deltas.json
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/foursquaretky_dataset/recommendations/foursquaretky_sample-SimpleX-Oct-26-2024_18-59-33/cp/gridsearch_results.json
# Processing model BPR on dataset gowalla
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_group["item_pop_group"] = "h"
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_group["item_pop_group"] = "t"
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_group["item_pop_group"] = "m"
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/gowalla_dataset/recommendations/gowalla_sample-BPR-Oct-26-2024_15-21-54/upd/top_k_recommendations.json
# Group: high - nDCG: 0.02000; ARP: 0.00252; Poplift: 2.52884
# Group: medium - nDCG: 0.00667; ARP: 0.00236; Poplift: 2.79277
# Group: low - nDCG: 0.00000; ARP: 0.00289; Poplift: 5.01803
# Group: all - nDCG: 0.00889; ARP: 0.00259; Poplift: 3.44654
# **************************************************
# Group: high - nDCG: 0.02000; ARP: 0.00252; Poplift: 2.50886
# Group: medium - nDCG: 0.00667; ARP: 0.00236; Poplift: 2.79536
# Group: low - nDCG: 0.00000; ARP: 0.00289; Poplift: 5.01803
# Group: all - nDCG: 0.00889; ARP: 0.00259; Poplift: 3.44075
# **************************************************
# Group: high - nDCG: 0.02000; ARP: 0.00252; Poplift: 2.51109
# Group: medium - nDCG: 0.00667; ARP: 0.00234; Poplift: 2.72574
# Group: low - nDCG: 0.00000; ARP: 0.00289; Poplift: 4.99721
# Group: all - nDCG: 0.00889; ARP: 0.00258; Poplift: 3.41135
# **************************************************
# Group: high - nDCG: 0.02000; ARP: 0.00251; Poplift: 2.50380
# Group: medium - nDCG: 0.00667; ARP: 0.00233; Poplift: 2.70613
# Group: low - nDCG: 0.00000; ARP: 0.00288; Poplift: 4.98070
# Group: all - nDCG: 0.00889; ARP: 0.00258; Poplift: 3.39688
# **************************************************
# Group: high - nDCG: 0.02000; ARP: 0.00249; Poplift: 2.43217
# Group: medium - nDCG: 0.00667; ARP: 0.00226; Poplift: 2.57357
# Group: low - nDCG: 0.00000; ARP: 0.00283; Poplift: 4.82479
# Group: all - nDCG: 0.00889; ARP: 0.00253; Poplift: 3.27684
# **************************************************
# Group: high - nDCG: 0.01262; ARP: 0.00241; Poplift: 2.39023
# Group: medium - nDCG: 0.00667; ARP: 0.00203; Poplift: 2.10475
# Group: low - nDCG: 0.00000; ARP: 0.00261; Poplift: 3.96951
# Group: all - nDCG: 0.00643; ARP: 0.00235; Poplift: 2.82150
# **************************************************
# Group: high - nDCG: 0.01262; ARP: 0.00225; Poplift: 2.00684
# Group: medium - nDCG: 0.00602; ARP: 0.00176; Poplift: 1.37040
# Group: low - nDCG: 0.00000; ARP: 0.00228; Poplift: 2.94438
# Group: all - nDCG: 0.00621; ARP: 0.00209; Poplift: 2.10721
# **************************************************
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/gowalla_dataset/recommendations/gowalla_sample-BPR-Oct-26-2024_15-21-54/cp/gridsearch_best_deltas.json
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/gowalla_dataset/recommendations/gowalla_sample-BPR-Oct-26-2024_15-21-54/cp/gridsearch_results.json
# Processing model LORE on dataset gowalla
# Error processing model LORE on dataset gowalla: 'score'
# Processing model USG on dataset gowalla
# Error processing model USG on dataset gowalla: 'score'
# Processing model SimpleX on dataset gowalla
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_group["item_pop_group"] = "h"
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_group["item_pop_group"] = "t"
# /var/folders/9q/p0b6nwnd5071040x3849mdvc0000gn/T/ipykernel_96319/1139550573.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_group["item_pop_group"] = "m"
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/gowalla_dataset/recommendations/gowalla_sample-SimpleX-Oct-26-2024_18-51-39/upd/top_k_recommendations.json
# Group: high - nDCG: 0.00000; ARP: 0.00225; Poplift: 2.82729
# Group: medium - nDCG: 0.00000; ARP: 0.00212; Poplift: 3.29579
# Group: low - nDCG: 0.00000; ARP: 0.00191; Poplift: 3.49209
# Group: all - nDCG: 0.00000; ARP: 0.00209; Poplift: 3.20506
# **************************************************
# Group: high - nDCG: 0.00000; ARP: 0.00225; Poplift: 2.82729
# Group: medium - nDCG: 0.00000; ARP: 0.00211; Poplift: 3.28877
# Group: low - nDCG: 0.00000; ARP: 0.00191; Poplift: 3.48018
# Group: all - nDCG: 0.00000; ARP: 0.00209; Poplift: 3.19874
# **************************************************
# Group: high - nDCG: 0.00000; ARP: 0.00225; Poplift: 2.78856
# Group: medium - nDCG: 0.00000; ARP: 0.00210; Poplift: 3.27761
# Group: low - nDCG: 0.00000; ARP: 0.00188; Poplift: 3.32355
# Group: all - nDCG: 0.00000; ARP: 0.00208; Poplift: 3.12991
# **************************************************
# Group: high - nDCG: 0.00000; ARP: 0.00224; Poplift: 2.78887
# Group: medium - nDCG: 0.00000; ARP: 0.00208; Poplift: 3.05947
# Group: low - nDCG: 0.00000; ARP: 0.00184; Poplift: 3.24403
# Group: all - nDCG: 0.00000; ARP: 0.00205; Poplift: 3.03079
# **************************************************
# Group: high - nDCG: 0.00000; ARP: 0.00216; Poplift: 2.47963
# Group: medium - nDCG: 0.00000; ARP: 0.00199; Poplift: 2.72519
# Group: low - nDCG: 0.00000; ARP: 0.00173; Poplift: 2.88506
# Group: all - nDCG: 0.00000; ARP: 0.00196; Poplift: 2.69662
# **************************************************
# Group: high - nDCG: 0.00000; ARP: 0.00199; Poplift: 2.34590
# Group: medium - nDCG: 0.00000; ARP: 0.00176; Poplift: 2.09094
# Group: low - nDCG: 0.00000; ARP: 0.00150; Poplift: 2.06209
# Group: all - nDCG: 0.00000; ARP: 0.00175; Poplift: 2.16631
# **************************************************
# Group: high - nDCG: 0.00000; ARP: 0.00180; Poplift: 2.45375
# Group: medium - nDCG: 0.00602; ARP: 0.00132; Poplift: 0.89399
# Group: low - nDCG: 0.00000; ARP: 0.00107; Poplift: 0.80156
# Group: all - nDCG: 0.00201; ARP: 0.00140; Poplift: 1.38310
# **************************************************
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/gowalla_dataset/recommendations/gowalla_sample-SimpleX-Oct-26-2024_18-51-39/cp/gridsearch_best_deltas.json
# Saved recommendations to /Volumes/Forster Neu/Masterarbeit Data/gowalla_dataset/recommendations/gowalla_sample-SimpleX-Oct-26-2024_18-51-39/cp/gridsearch_results.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 for dataset in available_datasets:
# ----> 2     data = dataset_metadata(dataset)
#       3     for result in data:
#       4         try:
#
# Cell In[2], line 5, in dataset_metadata(dataset, recommendation_dirpart)
#       2 def dataset_metadata(dataset, recommendation_dirpart=recommendation_dirpart):
#       3     data = []
# ----> 5     recs = os.listdir(f"{BASE_DIR}{dataset}_dataset/{recommendation_dirpart}")
#       6     if '.DS_Store' in recs:
#       7         recs.remove('.DS_Store')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/Forster Neu/Masterarbeit Data/snoward_dataset/recommendations'

# %%
cp_gridsearch_best_deltas
# Out:
# {'ndcg': {'high': 0.3, 'medium': 1, 'low': 0.9, 'all': 0.9},
#  'arp': {'high': 0, 'medium': 0, 'low': 0.1, 'all': 0},
#  'harmonic_mean': {'high': 0.3, 'medium': 1, 'low': 0.9, 'all': 0.9},
#  'js': {'high': 1, 'medium': 1, 'low': 1, 'all': 1},
#  'poplift': {'high': 1, 'medium': 1, 'low': 1, 'all': 1}}

# %%
base_eval = calculate_user_popularity_distributions(base_resample, item_popularity)

# %%
print("BASE")
group_means = evaluation_user_group_means(base_ndcg_scores, base_arp_scores, base_poplift_scores, user_groups)
print("RE_RANKED")
group_means = evaluation_user_group_means(calibrated_ndcg_scores, calibrated_arp_scores, calibrated_poplift_scores, user_groups)
# Out:
# BASE
# Group: high - nDCG: 0.02602; ARP: 0.02327; Poplift: -0.52907
# Group: medium - nDCG: 0.02811; ARP: 0.02305; Poplift: -0.44697
# Group: low - nDCG: 0.05530; ARP: 0.02309; Poplift: -0.25060
# Group: all - nDCG: 0.03648; ARP: 0.02314; Poplift: -0.40888
# **************************************************
# RE_RANKED
# Group: high - nDCG: 0.03332; ARP: 0.02790; Poplift: -0.43768
# Group: medium - nDCG: 0.03324; ARP: 0.02897; Poplift: -0.30888
# Group: low - nDCG: 0.07844; ARP: 0.02545; Poplift: -0.18206
# Group: all - nDCG: 0.04834; ARP: 0.02744; Poplift: -0.30954
# **************************************************

# %%
# List of algorithm DataFrames and their names
algorithm_dfs = {
    'BPR(Base)': base_df_general1,
    'BPR(Re-ranked)': calibrated_df_general1,
    'SimpleX(Re-ranked)': calibrated_df_general2,
    'SimpleX(Base)': base_df_general2,
    'LORE(Base)': base_df_context1,
    'LORE(Re-ranked)': calibrated_df_context1,
    'USG(Base)': base_df_context2,
    'USG(Re-ranked)': calibrated_df_context2
}

# Dictionary to store sorted frequencies for each algorithm
item_frequencies = {}

# Calculate frequency of each item in recommendations for each algorithm
for algorithm_name, df in algorithm_dfs.items():
    # Count item frequencies in each DataFrame
    item_counts = df['item_id:token'].value_counts(normalize=True)  # Normalize to get frequency
    sorted_counts = item_counts.sort_values(ascending=True).values  # Sort in descending order
    item_frequencies[algorithm_name] = sorted_counts  # Store sorted frequencies

# Plotting
plt.figure(figsize=(12, 6))

# Plot each algorithm's sorted item frequencies
for algorithm_name, frequencies in item_frequencies.items():
    plt.plot(frequencies, label=algorithm_name)

plt.xlabel('Items (sorted by frequency)')
plt.ylabel('Recommendation Frequency')
plt.title('Exposure Frequency of Items Recommended by Different Algorithms')
plt.legend(title='Algorithms')
plt.ylim(0, 0.045)  # Adjust as needed based on frequency range
plt.xlim(0, 8000)  # Adjust as needed based on frequency range
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 # List of algorithm DataFrames and their names
#       2 algorithm_dfs = {
# ----> 3     'BPR(Base)': base_df_general1,
#       4     'BPR(Re-ranked)': calibrated_df_general1,
#       5     'SimpleX(Re-ranked)': calibrated_df_general2,
#       6     'SimpleX(Base)': base_df_general2,
#       7     'LORE(Base)': base_df_context1,
#       8     'LORE(Re-ranked)': calibrated_df_context1,
#       9     'USG(Base)': base_df_context2,
#      10     'USG(Re-ranked)': calibrated_df_context2
#      11 }
#      13 # Dictionary to store sorted frequencies for each algorithm
#      14 item_frequencies = {}
#
# NameError: name 'base_df_general1' is not defined

# %% [markdown]
# ## Look more fine-grained at evaluation of specific user id

# %%
user_id = "311_x"

print(f"Base NDCG for user {user_id}: {base_ndcg_scores[user_id]}, Calibrated score: {calibrated_ndcg_scores[user_id]}")
print(f"Base ARP for user {user_id}: {base_arp_scores[user_id]}, Calibrated ARP: {calibrated_arp_scores[user_id]}")
print(f"Base Poplift for {user_id}: {base_poplift_scores[user_id]}, Calibrated Poplift: {calibrated_poplift_scores[user_id]}")
# Out:
# Base NDCG for user 311_x: 0, Calibrated score: 0
# Base ARP for user 311_x: 0.11826086956521735, Calibrated ARP: 0.05739130434782604
# Base Poplift for 311_x: 1.033644859813085, Calibrated Poplift: -0.013084112149532716

# %%
def open_context_info():
      # Stays the same across all models 
    # train_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/{dataset}_sample.train.inter", sep="\t")
    # test_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset//{dataset}_sample.test.inter", sep="\t")
    # valid_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/{dataset}_sample.valid.inter", sep="\t")
    item_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/processed_data_recbole/{dataset}_sample.item", sep="\t")
    # #valid_data = pd.read_csv(f"{BASE_DIR}{dataset}_dataset/processed_data_recbole/{dataset}_sample.valid.inter", sep="\t") # originale struktur !!!
    # train_data = pd.concat([train_data, valid_data])



    return item_data #,user_groups

# %%
item_data = open_context_info()

# %%
advanced_users = list(train_data.loc[train_data["item_id:token"] == "128_x"]["user_id:token"])
#user_id = advanced_users[0]

# %%
def specific_user_rec_sampler(df, user_id, item_data=item_data):

    user_recs = df.loc[df['user_id:token'] == user_id]

    #user_recs = base_df_general1.loc[base_df_general1['user_id:token'] == user_id]
    user_recs = user_recs.merge(item_data, on="item_id:token", how="left")
    return user_recs

# %%
user_recs = specific_user_rec_sampler(base_df_context1, user_id)

# %%
import folium

def make_map(df):
    map_center = [df['lat:float'].mean(), df['lon:float'].mean()]
    map = folium.Map(location=map_center, zoom_start=5)

    # Add markers for each location
    for _, row in df.iterrows():
        folium.Marker(
            location=[row['lat:float'], row['lon:float']],
            popup=row['item_id:token'],
            tooltip=row['item_id:token']
        ).add_to(map)

    return map

# %%
user_ground_truth = train_data.loc[train_data['user_id:token'] == user_id].merge(item_data, on="item_id:token", how="left")

# %%
item_popularity
# Out:
#       item_id:token  business_popularity:float item_pop_group
# 30546        1020_x                   1.000000              h
# 2491          730_x                   0.926087              h
# 24326         212_x                   0.769565              h
# 1357          549_x                   0.721739              h
# 13510          46_x                   0.695652              h
# ...             ...                        ...            ...
# 14628        3821_x                   0.043478              t
# 7016         2809_x                   0.043478              t
# 24909        4048_x                   0.043478              t
# 25023         429_x                   0.043478              t
# 21046        4166_x                   0.043478              t
#
# [4510 rows x 3 columns]

# %%
user_recs.merge(item_popularity, on="item_id:token", how="left")
# Out:
#   user_id:token item_id:token                name:token_seq  lat:float  \
# 0         311_x        2609_x             Monsoon Chocolate  32.206491
# 1         311_x        2111_x          American Eat Company  32.203908
# 2         311_x        1722_x                  Roma Imports  32.214239
# 3         311_x        1302_x                 Welcome Diner  32.220974
# 4         311_x        1094_x  5 Points Market & Restaurant  32.212200
# 5         311_x        2052_x          Mi Nidito Restaurant  32.199964
# 6         311_x        1510_x              Insomnia Cookies  32.221883
# 7         311_x        1511_x                    Urban Pita  32.221883
# 8         311_x          61_x          OBON Sushi Bar Ramen  32.221800
# 9         311_x         847_x        Charro Steak & Del Rey  32.221077
#
#     lon:float                            category_name:token_seq  \
# 0 -110.965960   Themed Cafes, Desserts, Cafes, Restaurants, Food
# 1 -110.965138  Coffee & Tea, Beer, Wine & Spirits, Grocery, F...
# 2 -110.948824  Cheese Shops, Delis, Specialty Food, Restauran...
# 3 -110.957513  Restaurants, Nightlife, Comfort Food, Cocktail...
# 4 -110.969090  Restaurants, American (New), Delis, Vegetarian...
# 5 -110.965150  Restaurants, Mexican, Desserts, Food, Latin Am...
# 6 -110.965287  Ice Cream & Frozen Yogurt, Desserts, Food Deli...
# 7 -110.965623  Middle Eastern, Restaurants, Greek, Falafel, F...
# 8 -110.965922  Sushi Bars, Restaurants, Bars, Japanese, Ramen...
# 9 -110.967255          Diners, Restaurants, Steakhouses, Mexican
#
#    business_popularity:float item_pop_group
# 0                   0.073913              m
# 1                   0.160870              h
# 2                   0.047826              t
# 3                   0.165217              h
# 4                   0.121739              m
# 5                   0.060870              m
# 6                   0.043478              t
# 7                   0.043478              t
# 8                   0.108696              m
# 9                   0.069565              m

# %%
item_data.loc[item_data["item_id:token"] == "164_x"]
# Out:
#      item_id:token               name:token_seq  lat:float  lon:float  \
# 1892         164_x  Ronnie's Marcus Imax Cinema  38.527293 -90.362332
#
#            category_name:token_seq
# 1892  Arts & Entertainment, Cinema

# %%
map = make_map(item_data)

# %%
item_data["category_name:token_seq"].values.tolist()
# Out:
# ['Sushi Bars, Restaurants, Japanese',
#  'Korean, Restaurants',
#  'Restaurants, Italian',
#  'Eatertainment, Arts & Entertainment, Brewpubs, American (Traditional), Bakeries, Breweries, Food, Restaurants',
#  'Sports Bars, American (New), American (Traditional), Nightlife, Bars, Restaurants',
#  'Food, Beer, Wine & Spirits, Breweries',
#  'Nightlife, Pubs, Event Planning & Services, Wine Bars, Bars, Gastropubs, Restaurants, Venues & Event Spaces',
#  'Ice Cream & Frozen Yogurt, Coffee & Tea, Restaurants, Sandwiches, Food',
#  'Restaurants, Seafood, Cajun/Creole',
#  'Bars, Beer Gardens, Food, Breweries, Nightlife, Tours, Pubs, Wine Tours, Beer Tours, Hotels & Travel',
#  'Venues & Event Spaces, Performing Arts, Arts & Entertainment, Hotels & Travel, Food, Convenience Stores, American (New), Beauty & Spas, Restaurants, Museums, Event Planning & Services, Hotels, Cinema, Resorts, Day Spas',
#  'Steakhouses, Restaurants, Sushi Bars, Japanese',
#  'Restaurants, Salad, Pakistani, Indian, Cocktail Bars, Food, Food Delivery Services, Soup, Halal, Bars, Nightlife',
#  'Restaurants, Mexican',
#  'Pizza, Fast Food, Gluten-Free, Restaurants, Salad',
#  'Restaurants, American (New), Breakfast & Brunch, Burgers',
#  'Restaurants, Italian, Nightlife, Southern, Bars, Breakfast & Brunch, Pizza',
#  'Event Planning & Services, Whiskey Bars, American (New), American (Traditional), Venues & Event Spaces, Bars, Nightlife, Restaurants',
#  'Books, Mags, Music & Video, Comic Books, Shopping, Bookstores',
#  'Bars, Breakfast & Brunch, Restaurants, American (New), Coffee & Tea, Food, Nightlife, Vegetarian',
#  'Cajun/Creole, Seafood, Noodles, Restaurants',
#  'Pakistani, Indian, Restaurants',
#  'Restaurants, Caterers, Barbeque, American (Traditional), Event Planning & Services',
#  'Bars, Nightlife, American (Traditional), Music Venues, Food, Arts & Entertainment, Restaurants, Breweries',
#  'Mexican, Restaurants',
#  'Pasta Shops, Bars, Nightlife, Specialty Food, Cocktail Bars, Breakfast & Brunch, Restaurants, Pizza, Food, Italian',
#  'Bars, Nightlife, Mexican, Restaurants, Seafood',
#  'Restaurants, Vegan, Vegetarian',
#  'Japanese, Sushi Bars, Food, Restaurants, Asian Fusion, Poke, Acai Bowls',
#  'Diners, Restaurants, Sandwiches, Breakfast & Brunch, Vegetarian',
#  'Restaurants, Breakfast & Brunch, Steakhouses, Sandwiches',
#  'Restaurants, Cajun/Creole, Seafood, Southern',
#  'Automotive, Restaurants, Sandwiches, Bars, Nightlife, Pubs, American (Traditional), Burgers, Beer Bar, Sports Bars, Breakfast & Brunch',
#  'Bars, Breakfast & Brunch, Restaurants, Barbeque, Cajun/Creole, Cafes, Cocktail Bars, Nightlife',
#  'Japanese, Asian Fusion, Wine Bars, Bars, Restaurants, Sushi Bars, Nightlife',
#  'Greek, Restaurants, Mediterranean',
#  'Latin American, Restaurants, Peruvian, Seafood',
#  'Event Planning & Services, Food, Sandwiches, Bakeries, Restaurants, American (New), Caterers',
#  'Sports Bars, Breakfast & Brunch, Mexican, Nightlife, Tex-Mex, Restaurants, Sandwiches, Bars',
#  'Restaurants, Soul Food, Southern, Soup, Sandwiches, Barbeque, Comfort Food',
#  'Restaurants, Cajun/Creole',
#  'Restaurants, Food, Coffee & Tea',
#  'Ramen, Japanese, Restaurants',
#  'Restaurants, Malaysian, Burmese, Asian Fusion, Thai',
#  'Mexican, Sandwiches, Restaurants',
#  'Cafes, Food, Bakeries, Restaurants',
#  'Restaurants, Pizza, Indian, Vegetarian',
#  'Breakfast & Brunch, American (Traditional), Korean, Restaurants, Gastropubs, Nightlife, Bars, Cocktail Bars',
#  'Restaurants, Mexican',
#  'Ramen, Restaurants, Tapas/Small Plates, Nightlife, Japanese, Bars, Cocktail Bars',
#  'Pubs, Gastropubs, Bars, Nightlife, American (New), Restaurants',
#  'Mexican, Restaurants',
#  'Sushi Bars, Restaurants',
#  'Japanese, Sushi Bars, Restaurants',
#  'Bars, Beer, Wine & Spirits, Restaurants, Lounges, Tapas/Small Plates, Mediterranean, Food, Nightlife',
#  'Arts & Entertainment, Cinema',
#  'Restaurants, Persian/Iranian, Mediterranean',
#  'Restaurants, Vegetarian, Salad, Wraps',
#  'Pizza, Food, Bagels, Sandwiches, Comfort Food, Breakfast & Brunch, Burgers, American (New), Nightlife, Bars, Wine Bars, Restaurants',
#  'Restaurants, Chinese, Szechuan',
#  'Comedy Clubs, Nightlife, Dance Clubs',
#  'Food, Donuts, Burgers, American (Traditional), Coffee & Tea, Restaurants',
#  'Sushi Bars, Restaurants',
#  'Laotian, American (Traditional), Asian Fusion, Salad, Pan Asian, Sushi Bars, Food Trucks, Food, Noodles, Restaurants, Thai',
#  'American (Traditional), Burgers, Bars, Restaurants, Pubs, Beer Bar, American (New), Nightlife',
#  'Coffee & Tea, New Mexican Cuisine, Restaurants, Tacos, Acai Bowls, Food, Nightlife, Mexican, Bars, Juice Bars & Smoothies',
#  'Restaurants, Mexican, Delis, Breakfast & Brunch, Food, Grocery, Sandwiches, Tacos',
#  'Restaurants, Breakfast & Brunch',
#  'Restaurants, American (Traditional), Cafes, Breakfast & Brunch',
#  'Restaurants, Cocktail Bars, Bars, Comfort Food, American (New), Sandwiches, Nightlife, Breakfast & Brunch',
#  'Italian, Local Flavor, Restaurants',
#  'Breweries, Nightlife, Chicken Wings, Pizza, Food, Restaurants, Beer Gardens, Pubs, Bars',
#  'Restaurants, Caribbean',
#  'Food, Juice Bars & Smoothies, Coffee & Tea, Restaurants, Bakeries, Cafes',
#  'Hair Stylists, Hair Salons, Beauty & Spas, Blow Dry/Out Services',
#  'Restaurants, Bars, Nightlife, American (Traditional), Cajun/Creole, Seafood',
#  'Pubs, Breweries, Bars, Nightlife, Food',
#  'Bars, Coffee & Tea, Restaurants, Cafes, Food, Nightlife, Breakfast & Brunch, Wine Bars, Sandwiches',
#  'American (New), Restaurants, Cajun/Creole',
#  'Food, Coffee Roasteries, Coffee & Tea',
#  'Coffee Roasteries, Food, Coffee & Tea',
#  'Restaurants, Pubs, Food, Bars, American (New), Nightlife',
#  'Food, Breweries',
#  'American (New), Breakfast & Brunch, Bars, Nightlife, Restaurants',
#  'Restaurants, Japanese, Asian Fusion, Sushi Bars, Teppanyaki',
#  'Vietnamese, Restaurants, Food, Thai, Coffee & Tea, Laotian',
#  'Restaurants, Tacos, Mexican',
#  'Food, Ice Cream & Frozen Yogurt',
#  'Bars, Nightlife, Lounges, Cocktail Bars',
#  'Nightlife, Sports Bars, Bars, Breweries, Pubs, Restaurants, American (Traditional), Food',
#  'Wine Bars, Bars, Southern, Nightlife, Tapas Bars, Restaurants, Breakfast & Brunch',
#  'Bars, Salad, Restaurants, Nightlife, Beer Bar, Italian',
#  'Beer, Wine & Spirits, Cafes, Coffee & Tea, Restaurants, Food, Breakfast & Brunch, American (New)',
#  'American (Traditional), Restaurants, Venues & Event Spaces, Event Planning & Services, Breakfast & Brunch, Bars, Nightlife',
#  'Restaurants, Delis, Sandwiches, Fast Food',
#  'Brewpubs, Restaurants, Breweries, Beer Bar, American (New), Nightlife, Bars, Pubs, Burgers, Pizza, Food',
#  'Vietnamese, Vegetarian, Noodles, Home Cleaning, Soup, Home Services, Thrift Stores, Shopping, Restaurants',
#  'Asian Fusion, Desserts, Sushi Bars, Food, Japanese, Restaurants',
#  'Nightlife, Food, Bars, Breweries, Pizza, Brewpubs, Pubs, Restaurants',
#  'Coffee & Tea, Cafes, Food, Creperies, Internet Cafes, Restaurants, Breakfast & Brunch',
#  'Coffee & Tea, Food',
#  'Arts & Entertainment, Restaurants, Cocktail Bars, American (New), Nightlife, Jazz & Blues, Steakhouses, American (Traditional), Bars',
#  'Delis, Bakeries, Food, Grocery, Restaurants',
#  'Breweries, Food',
#  'Tapas/Small Plates, Bars, Restaurants, Nightlife',
#  'Restaurants, Vegan, Soul Food',
#  'Restaurants, Dim Sum, Chinese, Cantonese, Noodles, Taiwanese, Szechuan',
#  'Nightlife, Cocktail Bars, Japanese, Restaurants, Thai, Asian Fusion, Bars',
#  'Pizza, Restaurants, Gluten-Free, Vegan',
#  'Specialty Food, Food, American (Traditional), Diners, Restaurants, Candy Stores',
#  'Food, Restaurants, Cuban, Coffee & Tea, Cafes, Sandwiches',
#  'Grocery, Desserts, Breakfast & Brunch, Food, Bakeries, Restaurants, Cafes, Coffee & Tea, Sandwiches',
#  'Street Vendors, Restaurants, Mexican, Food Trucks, Food, Seafood',
#  'Breweries, Food, Bars, Beer Bar, Nightlife, Brewpubs',
#  'Food, Restaurants, Brasseries, Breweries, Distilleries, Gastropubs',
#  'Breweries, Bars, Community Service/Non-Profit, Beer, Wine & Spirits, Beer Bar, Sandwiches, Food, Nightlife, Shopping, Used Bookstore, Restaurants, Local Services',
#  'Food, Farmers Market, Local Flavor',
#  'Music Venues, Bars, Restaurants, Italian, Steakhouses, Nightlife, Arts & Entertainment, Cocktail Bars',
#  'Active Life, Playgrounds, Parks, Fishing',
#  'Ice Cream & Frozen Yogurt, Desserts, Food Delivery Services, Bakeries, Food',
#  'Restaurants, Pizza, Italian, Salad',
#  'Bars, Pubs, Food, Nightlife, Restaurants, Breweries, American (New)',
#  'Wine Bars, Desserts, Bars, American (New), Nightlife, Restaurants, Italian, Food, Salad, Breakfast & Brunch, Pizza',
#  'Japanese, Restaurants, Ramen, Sushi Bars',
#  'Restaurants, Food, Beer, Wine & Spirits, Nightlife, British, American (Traditional), American (New), Chicken Wings, Bars, Pubs',
#  'Burgers, Restaurants, Fast Food, American (Traditional), Sandwiches, Diners',
#  'Tacos, Mexican, Specialty Food, Restaurants, Food',
#  'German, Restaurants, Seafood, Cocktail Bars, French, Brasseries, American (New), Nightlife, Bars, Cajun/Creole, Breakfast & Brunch',
#  'Bars, Restaurants, Food, Nightlife, Vietnamese, Bubble Tea',
#  'Breakfast & Brunch, Sandwiches, Restaurants, Event Planning & Services, Caterers, Chicken Shop, Fast Food',
#  'Nightlife, Bars, Speakeasies, Lounges, Dive Bars, Cocktail Bars, Pubs',
#  'Latin American, Restaurants, Mexican, Tex-Mex',
#  'Food, Coffee & Tea',
#  'Breakfast & Brunch, Coffee & Tea, Food, Restaurants',
#  'Restaurants, Street Vendors, Wine Bars, Food, Event Planning & Services, Bars, Mediterranean, Greek, Nightlife, Caterers',
#  'Breweries, Beer, Wine & Spirits, Food',
#  'Food, Restaurants, Bakeries, Coffee & Tea, Caterers, Event Planning & Services, Burgers, Breakfast & Brunch',
#  'Sandwiches, Restaurants, American (New), American (Traditional), Breakfast & Brunch',
#  'Bars, Restaurants, Sports Bars, Burgers, Pubs, Nightlife, Armenian, American (Traditional)',
#  'Music Venues, Arts & Entertainment, Event Planning & Services, Venues & Event Spaces, Nightlife, Jazz & Blues',
#  "Toy Stores, Shopping, Arts & Entertainment, Museums, Local Flavor, Children's Museums",
#  'American (Traditional), Breakfast & Brunch, Cafes, Restaurants',
#  'Hair Removal, Waxing, Skin Care, Health & Medical, Massage, Beauty & Spas, Massage Therapy',
#  'Restaurants, Tacos, Mexican, Hot Dogs, Breakfast & Brunch, Steakhouses',
#  'Food, Cafes, Coffee & Tea, Restaurants',
#  'Wholesalers, Professional Services, Italian, American (Traditional), Sandwiches, Specialty Food, Delis, Meat Shops, Butcher, Restaurants, Burgers, Food, Grocery, American (New)',
#  'Restaurants, Mexican, Breakfast & Brunch',
#  'Restaurants, Food, Beer, Wine & Spirits, Breweries, Mexican',
#  'Food, Coffee & Tea, Coffee Roasteries',
#  'Ice Cream & Frozen Yogurt, Food, American (New), Art Galleries, Shopping, Cocktail Bars, Arts & Entertainment, Restaurants, Nightlife, Chocolatiers & Shops, Specialty Food, Bars',
#  'Nightlife, Bars',
#  'American (Traditional), Restaurants, Breakfast & Brunch, Food, Coffee & Tea, Cafes',
#  'Sandwiches, Breakfast & Brunch, Cajun/Creole, Cafes, Food, Restaurants, Donuts',
#  'Event Planning & Services, Art Galleries, Hotels, Arts & Entertainment, Hotels & Travel, Lounges, Bars, Shopping, Food, Nightlife, Coffee & Tea',
#  'Event Planning & Services, Gift Shops, Home Decor, Cards & Stationery, Jewelry, Arts & Crafts, Home & Garden, Shopping, Flowers & Gifts',
#  'Nightlife, Bars, American (New), Restaurants, Wine Bars',
#  'Bars, British, Pubs, Nightlife, Pizza, Restaurants, Chicken Wings',
#  'American (Traditional), Restaurants, Cafes, Comfort Food, Vegetarian, Breakfast & Brunch, American (New)',
#  'Dive Bars, American (Traditional), Nightlife, Restaurants, Bars',
#  'Bars, Cuban, Wine Bars, Nightlife, Tex-Mex, Restaurants, Latin American, Mexican',
#  'Food, Coffee & Tea',
#  'Restaurants, Cafes, Korean, Gluten-Free, Comfort Food, Vegetarian, Vegan, Chicken Wings',
#  'Sushi Bars, Pubs, Gastropubs, Japanese, Restaurants, Czech, Nightlife, Bars',
#  'Caterers, Cafes, Event Planning & Services, Food, Cupcakes, Bakeries, Restaurants, Desserts',
#  'Burgers, Nightlife, Cajun/Creole, Bars, Restaurants, Seafood',
#  'Chinese, Restaurants, Barbeque',
#  'Food, Coffee & Tea, Juice Bars & Smoothies',
#  'Nightlife, Bars, Restaurants, American (Traditional)',
#  'Sandwiches, Desserts, Salad, Restaurants, Food, Delis',
#  'Breweries, Venues & Event Spaces, Beer Bar, Food, Pubs, Tours, Nightlife, Restaurants, Event Planning & Services, Hotels & Travel, Bars, Beer Tours, Arts & Entertainment, American (Traditional), Gastropubs, Music Venues, American (New)',
#  'Vegetarian, Restaurants, Breakfast & Brunch, Cafes, Juice Bars & Smoothies, Sandwiches, Food',
#  'Adult Entertainment, Sports Bars, Restaurants, Eatertainment, Pool Halls, Bars, Active Life, Arts & Entertainment, American (Traditional), Bowling, Arcades, Nightlife',
#  'Restaurants, Greek, Mediterranean',
#  'Local Flavor, Festivals, Arts & Entertainment',
#  "Museums, Arts & Entertainment, Children's Museums",
#  'Ethiopian, Restaurants, Vegan, Vegetarian',
#  'Lounges, Restaurants, Asian Fusion, Mexican, Latin American, Nightlife, Bars',
#  'American (New), Restaurants, American (Traditional), Food, Breakfast & Brunch, Coffee & Tea, Pizza',
#  'Restaurants, Barbeque, Mongolian',
#  'Juice Bars & Smoothies, Poke, Food, Hawaiian, Restaurants, Acai Bowls',
#  'Nightlife, Performing Arts, Arts & Entertainment',
#  'Event Planning & Services, Venues & Event Spaces',
#  'Restaurants, Steakhouses',
#  'American (Traditional), Restaurants, Bars, Seafood, Nightlife',
#  'Cajun/Creole, Seafood, Restaurants, Breakfast & Brunch',
#  'American (New), Breweries, Food, American (Traditional), Restaurants, Gastropubs',
#  'Grocery, Burgers, Food, Local Flavor, Restaurants, Salad, American (Traditional), Nightlife, American (New), Bars, Sandwiches, Breakfast & Brunch',
#  'Bars, Pizza, Sandwiches, Nightlife, Restaurants',
#  'Bars, Restaurants, Tex-Mex, Nightlife, American (Traditional)',
#  'New Mexican Cuisine, Mexican, Tex-Mex, Tacos, Restaurants',
#  'Restaurants, Sushi Bars',
#  'Donuts, Restaurants, Food',
#  'Chicken Wings, Restaurants, Sports Bars, Breakfast & Brunch, Burgers, Bars, Beer Bar, Nightlife, Pubs',
#  'Restaurants, Food, Vietnamese',
#  'Restaurants, Fruits & Veggies, French, Caterers, Food, Event Planning & Services, Specialty Food, Bakeries, Sandwiches, Cafes, Breakfast & Brunch',
#  'Breakfast & Brunch, Restaurants, Diners, Cafes',
#  'Vegan, Vegetarian, Restaurants',
#  'Restaurants, Cuban, Soul Food',
#  'Restaurants, Chinese, Szechuan, Noodles',
#  'Restaurants, Caterers, Italian, Hot Dogs, Pizza, Event Planning & Services, Sandwiches',
#  'Fitness & Instruction, Trainers, Active Life, Gyms, Interval Training Gyms',
#  'Animal Shelters, Veterinarians, Pet Sitting, Pet Services, Pet Stores, Pets',
#  'Sandwiches, Food, Burgers, Restaurants, Vegan, Desserts',
#  'Mediterranean, Falafel, Restaurants, Fast Food',
#  'Wine Bars, Restaurants, Diners, Bars, American (New), Seafood, American (Traditional), Steakhouses, Nightlife',
#  'Tacos, Restaurants, Mexican',
#  'Cupcakes, Caterers, Food, Chocolatiers & Shops, Bakeries, Specialty Food, Breakfast & Brunch, Shopping, Desserts, Restaurants, Event Planning & Services',
#  'Bars, Nightlife, American (Traditional), Restaurants, Breakfast & Brunch',
#  'Barbeque, Restaurants, Dive Bars, Cocktail Bars, Southern, Nightlife, Bars',
#  'Local Flavor, Ice Cream & Frozen Yogurt, Food',
#  'Local Flavor, Event Planning & Services, American (Traditional), Bars, Nightlife, Restaurants, Gastropubs, Venues & Event Spaces',
#  'Bars, Nightlife, Steakhouses, Restaurants',
#  'Restaurants, Bars, Tapas/Small Plates, Nightlife, American (New), Venues & Event Spaces, Event Planning & Services, Wine Bars',
#  'Breakfast & Brunch, Restaurants, Cafes, American (New), American (Traditional)',
#  'Cideries, Wine Bars, Shopping, Beer, Wine & Spirits, Venues & Event Spaces, Event Planning & Services, Nightlife, Bars, Breweries, Local Flavor, Food, Art Galleries, Wine Tasting Room, Wineries, Arts & Entertainment',
#  'Active Life, Beer Gardens, Grocery, Middle Eastern, Specialty Food, American (New), Parks, Cafes, Food, Nightlife, Restaurants, Coffee & Tea, Lebanese',
#  'Mexican, Restaurants',
#  'Juice Bars & Smoothies, Food, Mediterranean, Greek, Restaurants, Sandwiches',
#  'Local Flavor, Arts & Entertainment, Festivals',
#  'Seafood, Cajun/Creole, Restaurants, Comfort Food',
#  'Vietnamese, Restaurants',
#  'Mexican, Bars, Restaurants, Nightlife',
#  'Stadiums & Arenas, Nightlife, Music Venues, Arts & Entertainment',
#  'Restaurants, American (New)',
#  'Food, Cupcakes, Desserts, Bakeries',
#  'Food, Bakeries, Greek, Restaurants, Soup',
#  'Bars, American (New), Nightlife, Restaurants',
#  'Specialty Food, Shopping, Beer, Wine & Spirits, Flowers & Gifts, Food, Florists, Grocery',
#  'Sushi Bars, Poke, Restaurants, Hawaiian, Asian Fusion, Food',
#  'Southern, Breakfast & Brunch, Restaurants',
#  'Seafood, Restaurants',
#  'Burgers, American (Traditional), Restaurants, Breakfast & Brunch, Food, Beer, Wine & Spirits',
#  'American (Traditional), Bars, Nightlife, Restaurants, Beer Bar, Gastropubs, Breakfast & Brunch, Tapas/Small Plates',
#  'Cafes, Restaurants',
#  'Chinese, Food, Bubble Tea, Restaurants, Dim Sum, Szechuan',
#  'African, Venues & Event Spaces, Steakhouses, Restaurants, Seafood, American (New), Event Planning & Services',
#  'Salad, Pizza, Barbeque, Soup, Restaurants, Taiwanese, Chinese',
#  'Nightlife, Bars, Seafood, Restaurants',
#  'Restaurants, Italian',
#  'Sandwiches, Burgers, Restaurants, Steakhouses, American (New)',
#  'Nightlife, Restaurants, Southern, American (Traditional), Beer Bar, Bars',
#  'Restaurants, Cafes, Diners, Breakfast & Brunch, Burgers',
#  'Nightlife, Restaurants, Wine Bars, Bars, Tapas/Small Plates, Cocktail Bars, American (New)',
#  'Specialty Food, Delis, Coffee Roasteries, Butcher, Meat Shops, Food, Restaurants, Grocery, Italian',
#  'American (Traditional), Breakfast & Brunch, Cafes, Restaurants',
#  'Restaurants, Chinese, Szechuan',
#  'Trainers, Active Life, Boot Camps, Gyms, Interval Training Gyms, Fitness & Instruction, Circuit Training Gyms',
#  'Cafes, American (Traditional), Vietnamese, Restaurants',
#  'Italian, Burgers, Restaurants, Gastropubs, Bars, American (New), Nightlife, Pizza',
#  'Sushi Bars, Japanese, Restaurants',
#  'Restaurants, French, Coffee & Tea, Bakeries, Breakfast & Brunch, Cafes, Food, Sandwiches',
#  'Bars, Nightlife, Arts & Entertainment, Restaurants, Arcades, Beer Bar, Cocktail Bars, Burgers, Chicken Wings',
#  'Public Transportation, Transportation, Train Stations, Public Services & Government, Hotels & Travel',
#  'Breakfast & Brunch, Food, Restaurants, Coffee & Tea',
#  'Restaurants, American (New), Cocktail Bars, Bars, Tex-Mex, American (Traditional), Barbeque, Nightlife',
#  'Restaurants, Sandwiches, Food, Breakfast & Brunch, Bakeries',
#  'Restaurants, Salad, Sushi Bars, Soup, Japanese',
#  'Nightlife, Cajun/Creole, Bars, Cocktail Bars, Restaurants, Seafood',
#  'Restaurants, Food, Specialty Food, Ethnic Food, African, Caribbean',
#  'Seafood, Burgers, Restaurants',
#  'Restaurants, Italian',
#  'Salad, Soup, Sandwiches, Restaurants, Comfort Food, Burgers',
#  'Local Flavor, Recreation Centers, Amateur Sports Teams, Active Life',
#  'Restaurants, Pizza',
#  'Latin American, Caribbean, Dominican, Mexican, Restaurants',
#  'Restaurants, Hotels & Travel, Hotels, Beauty & Spas, American (New), Day Spas, Event Planning & Services, Resorts',
#  'Cocktail Bars, Bars, Speakeasies, Food, Nightlife',
#  'Restaurants, American (Traditional), Italian',
#  'Restaurants, Nightlife, Pubs, Food, Bars, American (New), German, Coffee & Tea, American (Traditional), Beer Bar',
#  'Food, Juice Bars & Smoothies, Restaurants, Fast Food',
#  'Salad, Desserts, Food, Asian Fusion, Japanese, Chinese, Restaurants, Sushi Bars',
#  'Mexican, Restaurants, Nightlife, Bars, Venues & Event Spaces, Event Planning & Services',
#  'Real Estate, Venues & Event Spaces, Food, Home Services, Coffee & Tea, Sandwiches, Event Planning & Services, Restaurants, Breakfast & Brunch, Specialty Food, Creperies, Shared Office Spaces, Wedding Planning',
#  'Food, Grocery, Organic Stores, Specialty Food, Health Markets',
#  'Barbeque, Smokehouse, Food, Event Planning & Services, Southern, Restaurants, Caterers, Desserts',
#  'Mexican, Restaurants, Salad, Food, Bars, Nightlife',
#  'Coffee & Tea, Bakeries, Food, Cafes, Restaurants, Breakfast & Brunch',
#  'Cocktail Bars, Nightlife, Bars, Hawaiian, Restaurants',
#  'Breakfast & Brunch, Restaurants, Waffles, Diners, Sandwiches',
#  'American (New), Cocktail Bars, Seafood, Bars, Restaurants, Nightlife',
#  'Restaurants, Sports Bars, Gastropubs, Bars, Nightlife, American (New), American (Traditional)',
#  'Food, American (New), Nightlife, Bars, Empanadas, Latin American, Restaurants, Mexican, Tacos',
#  'Restaurants, Kebab, German',
#  'Restaurants, Food, Coffee & Tea',
#  'Middle Eastern, Greek, Restaurants, Lebanese, Mediterranean',
#  'Breakfast & Brunch, American (New), Restaurants',
#  'Peruvian, Burgers, Restaurants, Mexican, Latin American',
#  'Wine Bars, Seafood, Food, Nightlife, Restaurants, Italian, Bars, American (Traditional)',
#  'Restaurants, Chinese, Asian Fusion, Sushi Bars',
#  'Restaurants, American (Traditional), Bakeries, Food, Caterers, Event Planning & Services',
#  'Cinema, Arts & Entertainment',
#  'Kebab, Mediterranean, Greek, Restaurants, Sandwiches',
#  'Coffee & Tea, Nightlife, Food, Delis, Breakfast & Brunch, Cafes, Bars, Restaurants',
#  'Event Planning & Services, Casinos, Beauty & Spas, Venues & Event Spaces, Arts & Entertainment, Day Spas, Hotels, Hotels & Travel',
#  'Pop-up Shops, Shopping, Desserts, Food',
#  'Venues & Event Spaces, Event Planning & Services, Breakfast & Brunch, Bars, American (New), Restaurants, Cocktail Bars, Nightlife',
#  'Arts & Entertainment, Art Museums, Festivals, Shopping, Art Galleries, Venues & Event Spaces, Museums, Event Planning & Services',
#  'Food, Breweries',
#  'Arts & Entertainment, Cinema',
#  'Malaysian, Asian Fusion, Cambodian, Chinese, Restaurants, Thai',
#  'Thai, Chinese, Seafood, Restaurants',
#  'Books, Mags, Music & Video, Local Services, Bookstores, Used Bookstore, Community Service/Non-Profit, Education, Shopping, Adult Education, Arts & Entertainment, Cultural Center',
#  'Burgers, Vegetarian, Restaurants, Vegan',
#  'Event Planning & Services, Hotels & Travel, Hotels, Venues & Event Spaces',
#  'American (Traditional), Nightlife, Restaurants, American (New), Bars, Steakhouses',
#  'Restaurants, Mediterranean, Moroccan',
#  'Restaurants, Seafood, Southern, Steakhouses',
#  'Vietnamese, Chinese, Food, Restaurants',
#  'Sandwiches, Salad, American (New), American (Traditional), Pizza, Restaurants',
#  'Personal Chefs, Event Planning & Services, Restaurants, Caribbean, American (New), American (Traditional), French',
#  'Breakfast & Brunch, Juice Bars & Smoothies, Restaurants, Food, American (New)',
#  'Seafood, Nightlife, Sports Bars, Bars, Restaurants, American (New)',
#  'Mexican, Tex-Mex, Restaurants, Barbeque',
#  'Restaurants, Burgers, American (New), Fast Food',
#  'American (New), Restaurants, Cocktail Bars, Barbeque, Bars, Nightlife',
#  'Restaurants, Burgers, American (Traditional), Bars, Pubs, Nightlife',
#  "Shopping, Vegan, Vegetarian, Beer, Wine & Spirits, Sandwiches, Food, Bagels, Bakeries, Coffee & Tea, Men's Clothing, American (Traditional), Restaurants, Women's Clothing, Breakfast & Brunch, Acai Bowls, Fashion, Cafes",
#  'Restaurants, American (Traditional), Bars, Pubs, Nightlife, Gastropubs',
#  'Thai, Restaurants, Noodles',
#  'Breweries, Food',
#  'Dim Sum, Restaurants, Cantonese, Chinese',
#  'Event Planning & Services, Hotels & Travel, Hotels',
#  'Breakfast & Brunch, Restaurants, Mediterranean',
#  'Bars, Nightlife, Whiskey Bars, Burgers, Restaurants, American (New)',
#  'Pizza, Pubs, Bars, Nightlife, Restaurants',
#  'Restaurants, American (New), Sandwiches, Burgers',
#  'Pizza, Breakfast & Brunch, Nightlife, Sandwiches, Italian, Restaurants, Cheesesteaks, Food Delivery Services, Cocktail Bars, Sports Bars, Food, Bars',
#  'Bakeries, Coffee & Tea, Bars, Donuts, Beer Bar, Food, Bubble Tea, Restaurants, Nightlife, Breakfast & Brunch, Gluten-Free, Vegan, Cafes, Acai Bowls',
#  'Beauty & Spas, Piercing, Tattoo',
#  'Bars, Seafood, Sports Bars, American (Traditional), Sandwiches, Nightlife, Restaurants',
#  'Restaurants, Chicken Shop, Bubble Tea, Chicken Wings, Food, Korean',
#  'Restaurants, Food, Cheesesteaks, Food Trucks, Burgers',
#  'Indian, Sandwiches, Restaurants, Pizza',
#  'Restaurants, Breakfast & Brunch, Coffee & Tea, Burgers, Food',
#  'Restaurants, Italian, Pizza',
#  'Barbeque, American (Traditional), Arts & Entertainment, Southern, Breakfast & Brunch, Comfort Food, Nightlife, Music Venues, Restaurants, Food, Grocery',
#  'Event Planning & Services, Venues & Event Spaces, Convenience Stores, Food',
#  'Japanese, Restaurants, Sushi Bars',
#  'American (New), Bars, Food, Pubs, Breweries, Pizza, Restaurants, Nightlife',
#  'Shopping, Art Galleries, Venues & Event Spaces, Event Planning & Services, Active Life, Museums, Art Museums, Botanical Gardens, Arts & Entertainment, Parks',
#  'Pizza, Nightlife, Pubs, Restaurants, Bars, Food, Food Delivery Services',
#  'Gluten-Free, Food, American (Traditional), Wraps, Vegan, Juice Bars & Smoothies, Salad, American (New), Restaurants',
#  'Italian, Restaurants, Food Stands, Farmers Market, Food Trucks, Caterers, Pizza, Event Planning & Services, Food',
#  'Italian, Pizza, Restaurants, Salad',
#  'Bars, Nightlife, Food, Food Delivery Services, Restaurants, Pizza',
#  'Restaurants, Bakeries, Desserts, Patisserie/Cake Shop, American (Traditional), Cafes, Coffee & Tea, Cupcakes, French, Sandwiches, Food, American (New), Breakfast & Brunch',
#  'Sandwiches, Hot Dogs, Restaurants, Salad, Burgers',
#  'Breakfast & Brunch, Restaurants',
#  'American (Traditional), Restaurants, American (New)',
#  'Vegan, Restaurants',
#  'Fish & Chips, American (New), Restaurants, Breakfast & Brunch',
#  'Breweries, Food',
#  'Specialty Food, Seafood Markets, Seafood, Food, Restaurants',
#  'Food, Imported Food, Specialty Food, Indian, Restaurants, Ethnic Food, Buffets',
#  'Ice Cream & Frozen Yogurt, Burgers, Food, Nightlife, Beer Bar, Bars, Restaurants',
#  'Restaurants, Cajun/Creole',
#  'Food Trucks, Falafel, Food Stands, Food, Mediterranean, Restaurants, Middle Eastern',
#  'Bars, American (Traditional), Breakfast & Brunch, Music Venues, Arts & Entertainment, Nightlife, Restaurants',
#  'Hot Dogs, Vegetarian, Burgers, Restaurants, Food Stands, Sandwiches',
#  'Restaurants, Indian',
#  'Asian Fusion, Restaurants, Chinese, Japanese, Shanghainese, Pan Asian, Noodles',
#  'American (New), Cocktail Bars, Bars, Wine Bars, Nightlife, Restaurants',
#  'Bars, Nightlife, Restaurants, Music Venues, American (New), Arts & Entertainment, Event Planning & Services, Southern, Venues & Event Spaces',
#  'Bars, Restaurants, Nightlife, Wine Bars, American (New), Steakhouses, Seafood',
#  'Burgers, Restaurants',
#  'Head Shops, Beer, Wine & Spirits, Shopping, Tobacco Shops, Flowers & Gifts, Food, Grocery',
#  'Restaurants, Thai, Pan Asian, Sushi Bars, Japanese, Indonesian, Asian Fusion',
#  'Restaurants, Pizza, Salad, Italian',
#  'Event Planning & Services, Caterers, Barbeque, Specialty Food, Restaurants, Food Trucks, Food',
#  'Boat Charters, Event Planning & Services, Hotels & Travel, Boat Tours, Restaurants, Active Life, Tours, Boating',
#  'Food, Ice Cream & Frozen Yogurt, Desserts, Donuts',
#  'Ice Cream & Frozen Yogurt, Food, Local Flavor, Desserts',
#  'Wine Bars, Bars, Nightlife, American (New), Mediterranean, Restaurants',
#  'Latin American, Restaurants, Cuban, Local Flavor',
#  'Italian, Cuban, Restaurants',
#  'Asian Fusion, Chinese, Vietnamese, Bubble Tea, Food, Korean, Restaurants',
#  'Event Planning & Services, Hotels & Travel, Hotels',
#  'Caterers, American (Traditional), Restaurants, Breakfast & Brunch, American (New), Event Planning & Services, Sandwiches',
#  'Nightlife, Bars, Food, Breweries',
#  'Middle Eastern, American (New), Restaurants, Mediterranean, Southern',
#  'Food, Hotels, Coffee & Tea, Hotels & Travel, Restaurants, Casinos, Burgers, Bars, Nightlife, Arts & Entertainment, Event Planning & Services',
#  'Latin American, Restaurants, Caterers, Event Planning & Services, Salvadoran, Salad, Breakfast & Brunch, Mexican, Tacos',
#  'Delis, Bars, Restaurants, Nightlife, Pubs, American (Traditional), Sandwiches',
#  'Local Flavor, Dog Parks, Parks, Active Life, Public Art, Boating',
#  'Jazz & Blues, Bars, Arts & Entertainment, Beer, Wine & Spirits, Wine Bars, Food, Nightlife',
#  'Restaurants, Food, Mexican, American (New)',
#  'American (New), Cafes, Breakfast & Brunch, American (Traditional), Coffee & Tea, Food, Restaurants',
#  'Restaurants, Chinese, Soup, Dim Sum',
#  'Cocktail Bars, Asian Fusion, Restaurants, Bars, Nightlife, Soup, Sushi Bars, Salad',
#  'American (Traditional), Barbeque, Steakhouses, Restaurants',
#  'Active Life, Cycling Classes, Fitness & Instruction',
#  'Food, Restaurants, Chinese, Bubble Tea, Taiwanese',
#  'Cafes, Vegan, Vegetarian, Restaurants, Specialty Food, Food, Pasta Shops, Italian',
#  'Restaurants, Creperies, Ice Cream & Frozen Yogurt, Desserts, Patisserie/Cake Shop, Food',
#  'Coffee & Tea, Donuts, Restaurants, Sandwiches, Food',
#  'Event Planning & Services, Music Venues, Dance Clubs, Venues & Event Spaces, Arts & Entertainment, Bars, Nightlife',
#  'Cideries, Food, Bars, Beer, Wine & Spirits, Nightlife, Beer Bar, Kombucha, Cocktail Bars',
#  'Nightlife, Venues & Event Spaces, Indian, Bars, Buffets, Restaurants, Lounges, Soup, Event Planning & Services, Salad',
#  'Restaurants, Breakfast & Brunch',
#  'Restaurants, Japanese, Sushi Bars',
#  'Noodles, Japanese, Diners, Restaurants, Ramen',
#  'Nightlife, American (Traditional), Bars, Restaurants',
#  'Juice Bars & Smoothies, Noodles, Restaurants, Asian Fusion, Food, Salad, Vegetarian, Vegan',
#  'Restaurants, Vietnamese',
#  'Sushi Bars, Restaurants, Steakhouses, Japanese',
#  'American (Traditional), Steakhouses, Nightlife, Bars, Seafood, Restaurants, Lounges',
#  'American (New), Nightlife, Bars, Restaurants',
#  'Beer, Wine & Spirits, Wine Bars, Modern European, American (New), Cheese Shops, Specialty Food, Food, Restaurants, Bars, Nightlife',
#  'Restaurants, Italian, Salad',
#  'Breweries, Food, Local Flavor',
#  'Delis, Event Planning & Services, Caterers, Sandwiches, Restaurants',
#  'Restaurants, Donuts, Chicken Wings, Food, Coffee & Tea',
#  'Tiki Bars, Bars, Nightlife',
#  'Food, Mediterranean, Italian, Pizza, Restaurants',
#  'Nightlife, Food, Pizza, Brewpubs, Restaurants, Fish & Chips, American (New), Bars, Pubs, Breweries, Vegetarian',
#  'Active Life, Baseball Fields, Stadiums & Arenas, Arts & Entertainment',
#  'Beauty & Spas, Nail Salons',
#  'Food, Poke, Hawaiian, Sushi Bars, Salad, Restaurants',
#  'Restaurants, Coffee & Tea, Sandwiches, Desserts, Food, Breakfast & Brunch',
#  'Shopping, Shopping Centers',
#  'Southern, Restaurants, American (Traditional)',
#  'Restaurants, Mexican',
#  'Bars, Pubs, Nightlife, American (New), Restaurants',
#  'Sandwiches, American (New), Lounges, Nightlife, Bars, Restaurants, Breakfast & Brunch',
#  'Restaurants, Food, Pizza',
#  'Mexican, Burgers, Latin American, Restaurants, Caribbean',
#  'Sushi Bars, Bubble Tea, Hawaiian, Food, Poke, Restaurants',
#  'Food, American (New), Restaurants, Pizza, Breweries',
#  'Arts & Entertainment, Bars, Nightlife, Arcades',
#  'Seafood, Italian, Restaurants, Mediterranean',
#  'Caterers, Event Planning & Services, Restaurants, Italian',
#  'Lounges, Nightlife, Cocktail Bars, Bars',
#  'Restaurants, Burgers, Fast Food, American (New), Food, Ice Cream & Frozen Yogurt',
#  'Bars, Tapas/Small Plates, Seafood, Tapas Bars, Nightlife, Breakfast & Brunch, Restaurants, American (New)',
#  'Desserts, Event Planning & Services, Sandwiches, Restaurants, Food, Italian, Venues & Event Spaces',
#  'Tex-Mex, Mexican, Restaurants',
#  'American (New), American (Traditional), Nightlife, Restaurants, Bars, Sandwiches, Cocktail Bars',
#  'Cocktail Bars, Nightlife, Gastropubs, Sports Bars, Restaurants, American (New), Lounges, Bars',
#  'Mexican, Restaurants, Seafood, Nightlife, Bars',
#  'American (New), Cocktail Bars, Nightlife, Southern, Bars, Restaurants',
#  'Vegetarian, Restaurants, Thai',
#  'Local Flavor, Food, Brewpubs, Breweries, Restaurants, Pizza, American (Traditional), American (New)',
#  'Nightlife, Breweries, Food, Bars',
#  'Italian, Dive Bars, Sports Bars, Nightlife, Irish Pub, Restaurants, Bars, Pubs',
#  'Sandwiches, American (New), Restaurants, Salad, Soup, Tacos, Mexican',
#  'Seafood, Tex-Mex, Restaurants, Tacos, Mexican',
#  'Food, Grocery',
#  'Latin American, Caribbean, Breakfast & Brunch, Restaurants, Mexican',
#  'Restaurants, Italian, Pizza',
#  'Restaurants, Tapas Bars, Food, Nightlife, Bars, Event Planning & Services, Caterers, Seafood, American (New), Desserts, Venues & Event Spaces, Tapas/Small Plates, Breakfast & Brunch, American (Traditional)',
#  'Diners, Restaurants, Steakhouses, Mexican',
#  'Salad, Restaurants, Pizza, Fast Food',
#  'American (Traditional), Restaurants',
#  'Desserts, Wine Bars, Coffee & Tea, Food, American (New), Nightlife, Bars, Restaurants',
#  'Burgers, Steakhouses, American (Traditional), Salad, Restaurants, Seafood, Buffets',
#  'Bars, Tiki Bars, Restaurants, Nightlife, Mexican',
#  'Ice Cream & Frozen Yogurt, Food, Coffee & Tea',
#  'Cajun/Creole, Restaurants',
#  'Cajun/Creole, Restaurants',
#  'Barbeque, Southern, Pan Asian, Thai, Vietnamese, Asian Fusion, Salad, Restaurants',
#  'Restaurants, Korean, American (Traditional), Breakfast & Brunch, Donuts, Food, Coffee & Tea',
#  'Restaurants, Desserts, Ice Cream & Frozen Yogurt, Food',
#  'Desserts, Bakeries, Food, Restaurants',
#  'Restaurants, Sushi Bars, Japanese, Bubble Tea, Taiwanese, Food',
#  'Pizza, Beer, Wine & Spirits, Food, Nightlife, American (New), Italian, Restaurants, Breakfast & Brunch, Bars, American (Traditional)',
#  'Pizza, Restaurants',
#  'Restaurants, Food, Coffee & Tea',
#  'Restaurants, Nightlife, Sandwiches, Bars, Cocktail Bars, Breakfast & Brunch, Pizza',
#  'Hookah Bars, Lounges, Bars, Halal, Restaurants, Nightlife, Middle Eastern, Mediterranean, Syrian',
#  'Automotive, Arts & Entertainment, Event Planning & Services, Race Tracks, Stadiums & Arenas, Hotels, Restaurants, Hotels & Travel',
#  'Spanish, Restaurants, Breakfast & Brunch, Tapas Bars, Iberian',
#  'Active Life, Museums, Zoos, Arts & Entertainment',
#  'Bars, Wine Bars, Pizza, Sandwiches, Nightlife, Gluten-Free, Restaurants, Italian',
#  'Korean, Restaurants, Asian Fusion',
#  'Mexican, Restaurants, Vegetarian, Coffee & Tea, Juice Bars & Smoothies, Cafes, Desserts, Bakeries, Food, Breakfast & Brunch',
#  'Nightlife, Bars, Wine Bars, Soup, Restaurants, American (New)',
#  'Arts & Entertainment, Festivals, Local Flavor',
#  'Arts & Entertainment, Restaurants, Italian, Beer, Wine & Spirits, Fruits & Veggies, Farms, Specialty Food, Seafood, Food',
#  'Food, Bakeries, Coffee & Tea',
#  'Restaurants, Nightlife, Arts & Entertainment, Barbeque, Bars, Music Venues, American (Traditional)',
#  'German, Beer Bar, Food, Bars, Nightlife, Restaurants, Beer, Wine & Spirits, Beer Gardens',
#  'Tapas/Small Plates, Nightlife, Bars, Food Delivery Services, American (New), Southern, Restaurants, Tapas Bars, Food, Cooking Classes, Arts & Crafts, American (Traditional), Event Planning & Services, Wine Bars, Caterers, Shopping',
#  'Restaurants, Gastropubs, American (New)',
#  'Indian, Restaurants',
#  'Vietnamese, Restaurants',
#  'Ramen, Japanese, Restaurants',
#  'American (Traditional), Comfort Food, Desserts, Food, Restaurants, Salad, Burgers',
#  'Greek, Desserts, Mediterranean, American (New), Wraps, Specialty Food, Restaurants, Food',
#  'Zoos, Arts & Entertainment, Performing Arts, Active Life, Parks, Skating Rinks, Tennis, Museums, Public Services & Government, Golf, Landmarks & Historical Buildings',
#  'Restaurants, Pizza, Salad, Cafes, Food, Vegetarian, Desserts',
#  'Restaurants, Sushi Bars, Japanese',
#  'Mexican, Restaurants',
#  'Acai Bowls, Food Delivery Services, Salad, Poke, Juice Bars & Smoothies, American (Traditional), Food, American (New), Restaurants',
#  'Restaurants, Cambodian, Thai, Vietnamese, Asian Fusion',
#  'Salad, Fast Food, Restaurants, Pizza',
#  'Ice Cream & Frozen Yogurt, Coffee & Tea, Food, Gelato',
#  'American (New), Restaurants, French',
#  'Restaurants, Noodles, Asian Fusion, Japanese',
#  'Sandwiches, Restaurants, Delis, Fast Food',
#  'Event Planning & Services, Arts & Entertainment, Nightlife, Music Venues, Venues & Event Spaces',
#  'Desserts, Restaurants, Gluten-Free, Food, Salvadoran, Latin American, American (Traditional)',
#  'Seafood, Chinese, Asian Fusion, Restaurants, Korean',
#  'Ice Cream & Frozen Yogurt, Desserts, Food',
#  'Vietnamese, Restaurants',
#  'Restaurants, Halal, Middle Eastern, Mediterranean',
#  'Event Planning & Services, Food, Restaurants, Seafood, Seafood Markets, Caterers, Specialty Food, Cajun/Creole',
#  'American (New), Cocktail Bars, Salad, Breakfast & Brunch, Bars, Nightlife, Restaurants, Hotels & Travel',
#  'Beer, Wine & Spirits, Pizza, Restaurants, Italian, Food, Salad',
#  'Restaurants, Latin American, Caribbean, Sushi Bars, Seafood',
#  'Coffee & Tea, Bakeries, Donuts, American (Traditional), Food, Restaurants, Fast Food',
#  'Gastropubs, Cajun/Creole, Southern, Burgers, American (New), Restaurants',
#  'Delis, Restaurants, Japanese, Nightlife, Bars, Sushi Bars, Seafood, Wine Bars, Sandwiches, Asian Fusion',
#  'Bars, Restaurants, Sports Bars, Beer Bar, Music Venues, Salad, Nightlife, Arts & Entertainment, Pubs, Burgers, American (New), Chicken Wings',
#  'Restaurants, Specialty Food, Grocery, Fast Food, Coffee & Tea, Food, Health Markets, Beer, Wine & Spirits',
#  'Nightlife, Food, Bars, Pizza, Beer, Wine & Spirits, Beer Bar, Italian, Restaurants',
#  'Mexican, Gluten-Free, Vegetarian, Restaurants, Vegan',
#  'Restaurants, Chinese',
#  "Outdoor Gear, Fashion, Men's Clothing, Women's Clothing, Sporting Goods, Gun/Rifle Ranges, Shopping, Active Life",
#  'Coffee & Tea, Food, Restaurants, Coffee Roasteries, Sandwiches, Breakfast & Brunch, Desserts',
#  'Malaysian, Nightlife, Bars, Salad, Cocktail Bars, Tapas/Small Plates, Japanese, Restaurants, Ramen, Filipino, Pan Asian, Chinese, Asian Fusion',
#  'Restaurants, Pizza',
#  'Breakfast & Brunch, Bars, Nightlife, Restaurants, Gastropubs, Pubs',
#  'Public Services & Government, Public Markets, Event Planning & Services, Landmarks & Historical Buildings, Venues & Event Spaces, Local Flavor, Shopping',
#  'Seafood, American (Traditional), Nightlife, Restaurants, Lounges, Bars, American (New), Steakhouses',
#  'Bagels, Sandwiches, Food, Restaurants, Salad, Bakeries',
#  'Burgers, Restaurants, Salad, Steakhouses',
#  'Bars, Restaurants, Nightlife, Seafood',
#  'Breakfast & Brunch, Diners, Nightlife, Restaurants, Steakhouses, Bars',
#  'Nightlife, Breakfast & Brunch, Bars, Restaurants, American (Traditional)',
#  'Restaurants, Indian',
#  'Food, Restaurants, American (Traditional), Mexican, Tex-Mex, Food Trucks, Tacos',
#  'Burgers, Hot Dogs, Ice Cream & Frozen Yogurt, Food, Restaurants',
#  'Restaurants, Mexican',
#  'Laser Hair Removal, Tattoo Removal, Skin Care, Health & Medical, Body Contouring, Beauty & Spas, Doctors, Medical Spas, Permanent Makeup, Hair Removal',
#  'Indian, Restaurants, Pakistani',
#  'Southern, Restaurants, Sandwiches, Seafood',
#  'Bakeries, Breakfast & Brunch, Restaurants, Coffee & Tea, Sandwiches, Food, Vegan, Desserts',
#  'Food, Japanese, Restaurants, Poke, Sushi Bars',
#  'Restaurants, Cafes, Breakfast & Brunch, American (Traditional)',
#  'Restaurants, Food, Barbeque, Desserts',
#  'Cocktail Bars, American (Traditional), Bars, Restaurants, Nightlife, Beer Bar, Food, Beer, Wine & Spirits',
#  'Coffee & Tea, Restaurants, Food, Bubble Tea, Desserts, Creperies',
#  'Restaurants, Izakaya, Ramen, Japanese',
#  'Sandwiches, Salad, American (Traditional), Cheesesteaks, Breakfast & Brunch, Active Life, American (New), Beaches, Restaurants',
#  'Nightlife, Cocktail Bars, Bars, Restaurants, Tapas/Small Plates, American (New)',
#  'Restaurants, Indian, Pakistani, Seafood, Soup',
#  'Mongolian, Restaurants, Chinese, Hot Pot',
#  'Nightlife, Sports Bars, Pizza, Bars, Chicken Wings, Restaurants',
#  'Cajun/Creole, American (New), Restaurants',
#  'Arts & Entertainment, Cinema, Music Venues, Nightlife, Venues & Event Spaces, Event Planning & Services',
#  'Buffets, Pakistani, Restaurants, Indian, Vegan, Vegetarian',
#  'Restaurants, Seafood',
#  'Tacos, Nightlife, Bars, Mexican, Restaurants',
#  'Italian, Gluten-Free, Restaurants, Breakfast & Brunch',
#  'Coffee & Tea, Desserts, Local Flavor, Restaurants, Cafes, Food, Breakfast & Brunch',
#  'Restaurants, American (New), Distilleries, Breweries, Brewpubs, Nightlife, Food, Bars, Gastropubs, American (Traditional)',
#  'French, Wine Bars, Food, Specialty Food, Nightlife, Beer, Wine & Spirits, Restaurants, Bars',
#  'Restaurants, Desserts, Food, Salad, Seafood',
#  'Lounges, Juice Bars & Smoothies, Nightlife, Beer, Wine & Spirits, Food, Bars',
#  'Spanish, Cafes, Cuban, Latin American, Juice Bars & Smoothies, Food, Coffee & Tea, Restaurants',
#  'Mediterranean, Middle Eastern, Restaurants',
#  'Restaurants, Cheesesteaks, Sandwiches, Salad',
#  'American (New), Restaurants, American (Traditional)',
#  'Food, Restaurants, Bagels, Cafes, Coffee & Tea, Sandwiches, Breakfast & Brunch',
#  'Korean, Restaurants',
#  'Cuban, Sandwiches, Breakfast & Brunch, Spanish, Restaurants',
#  'Asian Fusion, Restaurants, Sushi Bars',
#  'American (Traditional), Restaurants, Bars, Nightlife, Burgers, Sandwiches, Soup, Pubs',
#  'Event Planning & Services, Chicken Shop, Caterers, Fast Food, Restaurants',
#  'Restaurants, Pakistani, Indian',
#  'Japanese, Sushi Bars, Restaurants',
#  'Wineries, Food, Arts & Entertainment',
#  'Cinema, Arts & Entertainment',
#  'New Mexican Cuisine, Breakfast & Brunch, Desserts, Nightlife, Bars, Cocktail Bars, Mexican, Latin American, Restaurants, Food, Tacos',
#  'Dim Sum, Japanese, Restaurants, Chinese',
#  'Restaurants, Vietnamese',
#  'Nightlife, Restaurants, Gastropubs, American (New), Comfort Food, Bars, Pubs',
#  'Restaurants, Vietnamese',
#  'Poke, Ice Cream & Frozen Yogurt, Food',
#  'Tapas Bars, Wine Bars, Beer, Wine & Spirits, Food, Bars, Restaurants, Nightlife',
#  'Sushi Bars, Japanese, Restaurants, Asian Fusion, Tapas/Small Plates',
#  'Nightlife, Comfort Food, Restaurants, American (New), American (Traditional), Soul Food, Southern, Bars, Beer Bar, Sandwiches',
#  'Food, Nightlife, Bars, Cocktail Bars, Beer, Wine & Spirits, Restaurants, Lawn Services, Food Court, Landscaping, Beer Gardens, Shopping, Real Estate, Shopping Centers, Home Services, Shared Office Spaces, Arts & Entertainment',
#  'Restaurants, Food, Pizza',
#  'Chicken Wings, Southern, Sandwiches, Chicken Shop, Restaurants, Breakfast & Brunch, Wraps, American (New), Tacos, American (Traditional), Mexican, Food, Donuts',
#  'Seafood, Restaurants, French',
#  'Arts & Entertainment, Active Life, Parks, Venues & Event Spaces, Stadiums & Arenas, Party Equipment Rentals, Event Planning & Services',
#  'Nightlife, Burgers, Restaurants, Mexican, Bars, Beer Bar, Hawaiian',
#  'Bars, Sandwiches, Breweries, Nightlife, Food, Restaurants, Beer Bar, Pizza',
#  'Restaurants, Event Planning & Services, Delis, Sandwiches, Salad, Caterers',
#  'Cafes, Coffee & Tea, Food, Latin American, Mexican, Burgers, Nightlife, Bars, Cuban, Cocktail Bars, Restaurants',
#  'Soul Food, Chicken Wings, Restaurants, Southern',
#  'Asian Fusion, Nightlife, Japanese, Restaurants, Sushi Bars, Karaoke',
#  'Food, Beer, Wine & Spirits, Nightlife, Restaurants, Bars, Cocktail Bars, Mexican',
#  'Beer, Wine & Spirits, Home Decor, Food, Shopping, Furniture Stores, Home & Garden',
#  'Vietnamese, Pan Asian, Restaurants',
#  'Restaurants, Thai',
#  'Seafood, Bars, American (New), Nightlife, Restaurants',
#  'Stadiums & Arenas, Arts & Entertainment',
#  'Restaurants, Barbeque, Seafood, Bars, Nightlife, Pubs, Caribbean',
#  'Venues & Event Spaces, Bars, Event Planning & Services, Nightlife, Jazz & Blues, Vegetarian, Cocktail Bars, Restaurants, Music Venues, Dive Bars, Arts & Entertainment',
#  'Burgers, Diners, Cajun/Creole, Barbeque, Music Venues, Restaurants, American (Traditional), Nightlife, Arts & Entertainment',
#  'American (New), Restaurants',
#  'Food, Desserts, Ice Cream & Frozen Yogurt, Juice Bars & Smoothies',
#  'Restaurants, Salad, Soup, Nightlife, Italian, Wine Bars, Bars',
#  'Food, Acai Bowls, Restaurants, Wraps, Cafes, Juice Bars & Smoothies',
#  'Playgrounds, Disc Golf, Dog Parks, Active Life, Hiking, Amusement Parks, Parks, Pets',
#  'Comfort Food, American (Traditional), Restaurants, Bakeries, Food, Diners, Ice Cream & Frozen Yogurt, Burgers',
#  'Food, Grocery, Beer, Wine & Spirits, Bakeries, Juice Bars & Smoothies, Coffee & Tea',
#  'Restaurants, Mexican, Food, Hawaiian, Poke, Japanese',
#  'Sushi Bars, Nightlife, Restaurants, Cocktail Bars, Japanese, Asian Fusion, Bars',
#  'Restaurants, Mexican, Tex-Mex',
#  'Breakfast & Brunch, Food, Burgers, Salad, Restaurants',
#  'Food, American (New), Restaurants, Beer, Wine & Spirits',
#  'Restaurants, Irish, Irish Pub, Sandwiches, Bars, Nightlife',
#  'Vietnamese, Restaurants',
#  'Ice Cream & Frozen Yogurt, Desserts, Bakeries, Cupcakes, Patisserie/Cake Shop, Food',
#  'Cocktail Bars, Food Delivery Services, Nightlife, Breakfast & Brunch, Food, Bars, Event Planning & Services, Caterers, Restaurants, Indian',
#  'Delis, Restaurants, Food, Ethnic Food, Meat Shops, Specialty Food',
#  'Food Trucks, Food, Restaurants, Mexican',
#  'Noodles, Restaurants, Indonesian',
#  'Restaurants, French, Wine Bars, Nightlife, American (New), Bars, Cafes, Breakfast & Brunch',
#  'American (New), Nightlife, Restaurants, Bars, Gastropubs, Local Flavor',
#  'Restaurants, Mexican, Comfort Food, New Mexican Cuisine, Food, Tacos',
#  'Restaurants, American (Traditional), Burgers, Local Flavor, Salad',
#  'Breakfast & Brunch, American (New), Nightlife, Bars, Restaurants, Cocktail Bars',
#  'Food, Ice Cream & Frozen Yogurt',
#  'Restaurants, French, Breakfast & Brunch',
#  'Lounges, Bars, Nightlife, Restaurants, Bar Crawl',
#  'Arts & Entertainment, Local Flavor, Museums',
#  'Arts & Entertainment, Festivals',
#  'Breakfast & Brunch, Restaurants, Vegetarian, Cafes, American (New), Food, Diners, American (Traditional)',
#  'Restaurants, Nightlife, Comfort Food, Cocktail Bars, Bars, Diners, American (Traditional), Breakfast & Brunch',
#  'Asian Fusion, Steakhouses, Japanese, Barbeque, Restaurants, Sushi Bars',
#  'Barbeque, Caterers, Restaurants, Event Planning & Services',
#  'Nightlife, Bars, Desserts, Food, Restaurants, Burgers, Comfort Food, Breakfast & Brunch, Cocktail Bars, American (Traditional)',
#  'Bars, Shopping, Military Surplus, Nightlife',
#  'Ethnic Food, International Grocery, Breakfast & Brunch, Specialty Food, Restaurants, Grocery, Food',
#  'Breweries, Nightlife, Restaurants, Food, American (New), Bars',
#  'Thai, Breakfast & Brunch, Chinese, American (Traditional), Restaurants, American (New)',
#  'Food, Coffee Roasteries, Coffee & Tea',
#  'Seafood, Cajun/Creole, Restaurants, Vegetarian',
#  'Bars, Nightlife, Kosher, Burgers, Tapas/Small Plates, American (Traditional), Vegan, Seafood, Cocktail Bars, Restaurants, Vegetarian',
#  'Japanese, Ramen, Ethnic Food, Restaurants, Local Flavor, Food, Specialty Food',
#  'Seafood, Greek, Food, Music Venues, American (New), Sandwiches, Breakfast & Brunch, Beer, Wine & Spirits, Restaurants, Bars, Arts & Entertainment, Nightlife, Burgers, Gastropubs',
#  'Japanese, Vietnamese, Restaurants, Chinese',
#  'Latin American, Tapas/Small Plates, Restaurants, Spanish',
#  'Restaurants, Seafood, American (New), Food, Beer, Wine & Spirits',
#  'Public Services & Government, Landmarks & Historical Buildings',
#  'Spanish, Restaurants, Lebanese, Middle Eastern, Venezuelan, Halal, Latin American',
#  'Hotels & Travel, Bed & Breakfast, Hotels, Nightlife, Event Planning & Services, Guest Houses, Lounges, Bars',
#  'Beer, Wine & Spirits, Burgers, Cocktail Bars, Bars, Gastropubs, Nightlife, Breakfast & Brunch, Food, Restaurants, Pubs, Venues & Event Spaces, Barbeque, Event Planning & Services, Sports Bars',
#  'Food, Cafes, Restaurants, Coffee & Tea, Breakfast & Brunch',
#  'Nightlife, American (Traditional), Restaurants, Bars, Lounges',
#  'Sandwiches, Restaurants, Breakfast & Brunch, Wine Bars, Nightlife, American (New), Bars, American (Traditional)',
#  'Ethiopian, Restaurants, Vegan',
#  'Japanese, Sushi Bars, Bars, Food, Restaurants, Bubble Tea, Cocktail Bars, Nightlife',
# ...
#  'Coffee & Tea, Tea Rooms, American (Traditional), Bakeries, Food, Restaurants, Coffee Roasteries, Bagels',
#  'Nightlife, Bars, Event Planning & Services, American (Traditional), Restaurants, Vegetarian, American (New), Venues & Event Spaces, Gluten-Free, Breakfast & Brunch',
#  'Barbeque, Soul Food, Comfort Food, American (Traditional), Southern, Restaurants',
#  'Gluten-Free, Seafood, Restaurants, Food, Sandwiches, Nightlife, Bars, Beer, Wine & Spirits',
#  'Nightlife, Restaurants, Bars, Dive Bars',
#  'Parks, Active Life',
#  'Bars, Restaurants, Burgers, Nightlife, American (New), American (Traditional), Pubs, Gastropubs',
#  'Cheesesteaks, Restaurants, Breakfast & Brunch, Sandwiches',
#  'Souvenir Shops, Medical Supplies, Local Services, Holiday Decorations, Costumes, Arts & Crafts, Shopping, Home & Garden, Community Service/Non-Profit',
#  'Beer Bar, Nightlife, Wine Bars, Pizza, Restaurants, Bars, Pubs',
#  'Restaurants, Seafood, Food, Desserts, Chicken Wings',
#  'Restaurants, American (Traditional), Breakfast & Brunch',
#  'Chicken Wings, Hot Dogs, Beer Bar, Salad, Bars, Nightlife, Restaurants, Burgers, American (Traditional)',
#  'American (New), Cafes, Bakeries, Bars, Wine Bars, Food, Nightlife, Restaurants',
#  'German, Restaurants, Bakeries, Beer Gardens, Food, Nightlife',
#  'Cafes, Restaurants, Greek, Delis, Caterers, Sandwiches, Event Planning & Services, Mediterranean',
#  'Taiwanese, Chinese, Shanghainese, Restaurants',
#  'Restaurants, Food, Local Flavor, Brewpubs, American (Traditional), Cuban, Breweries, Caribbean, Bars, Nightlife, Pubs',
#  'American (New), Cafes, Restaurants, Food',
#  'Italian, Restaurants',
#  'American (New), Restaurants, Pubs, Beer, Wine & Spirits, Pizza, Nightlife, Food, Bars',
#  'Tapas/Small Plates, American (Traditional), Beer, Wine & Spirits, Mediterranean, Restaurants, Food, Bars, Cocktail Bars, Nightlife',
#  'Arts & Entertainment, Restaurants, Skating Rinks, Festivals, Shopping, Food Stands, Public Markets, Active Life',
#  'Restaurants, Sandwiches, Southern, Salad, Chicken Shop',
#  'Restaurants, Gluten-Free, Bars, Food, Nightlife, Sandwiches, Burgers',
#  'Restaurants, Italian',
#  'Coffee & Tea, Pubs, Delis, Food, Vegan, Cuban, Restaurants, Bars, Nightlife',
#  'Cocktail Bars, Steakhouses, American (Traditional), Bars, Restaurants, Nightlife',
#  'Restaurants, Bars, Latin American, Nightlife, Colombian',
#  'Restaurants, Bars, Wine Bars, Mediterranean, Italian, Nightlife',
#  'Pizza, Sandwiches, Burgers, Restaurants',
#  'Italian, Food, Restaurants, Gelato',
#  'Restaurants, Chicken Wings, Pizza, American (Traditional), Nightlife, Bars, Sports Bars',
#  'Gastropubs, Bars, Burgers, Pizza, Restaurants, Nightlife, Breakfast & Brunch, American (Traditional), Cocktail Bars',
#  'Restaurants, American (Traditional), Chicken Wings, Southern, Chicken Shop',
#  'Restaurants, Barbeque, Nightlife, American (New), Bars, American (Traditional), Chicken Wings, Burgers, Seafood, Sports Bars',
#  'Japanese, Restaurants, Asian Fusion, Korean',
#  'Nail Salons, Waxing, Beauty & Spas, Hair Removal',
#  'Bars, Burgers, Chicken Wings, Restaurants, Pubs, Nightlife, American (Traditional), Irish',
#  'Restaurants, Steakhouses, American (Traditional)',
#  "Women's Clothing, Shopping, Men's Clothing, Fashion, Department Stores, Shoe Stores",
#  'Restaurants, Vietnamese',
#  'Food, Bakeries',
#  'Adult Education, Vegan, Local Flavor, Education, Festivals, Yelp Events, Restaurants, Arts & Entertainment',
#  'Active Life, Restaurants, Arts & Entertainment, Bars, Breakfast & Brunch, Beer Bar, Beer, Wine & Spirits, Tacos, Mexican, Bowling, Food, American (Traditional), Coffee & Tea, Eatertainment, Gastropubs, Nightlife, American (New)',
#  'Religious Organizations, Restaurants, Local Flavor, Thai, Buddhist Temples, Churches',
#  'Italian, Restaurants',
#  'Escape Games, Amusement Parks, Challenge Courses, Arts & Entertainment, Party & Event Planning, Event Planning & Services, Recreation Centers, Venues & Event Spaces, Active Life',
#  'Food, Cajun/Creole, Seafood Markets, Seafood, Specialty Food, Restaurants, French',
#  'American (Traditional), Gluten-Free, Food, Venues & Event Spaces, Mexican, Restaurants, Breakfast & Brunch, Hawaiian, Event Planning & Services',
#  'Lounges, Restaurants, Burgers, Bars, Vegetarian, Nightlife, Middle Eastern, Lebanese, Cocktail Bars, American (New)',
#  'American (New), Sandwiches, Food, Cajun/Creole, Restaurants',
#  'Food, Nightlife, Coffee & Tea, Beer, Wine & Spirits, Vinyl Records, Shopping, Beer Bar, Bars, Books, Mags, Music & Video',
#  'Restaurants, Sushi Bars',
#  'Nightlife, Wine Bars, Sports Bars, Beverage Store, Beer Bar, Restaurants, American (Traditional), Food, Bars',
#  'Hotels & Travel, Event Planning & Services, Hotels, Venues & Event Spaces',
#  'Arts & Entertainment, Cinema',
#  'Mexican, Restaurants',
#  'Tapas/Small Plates, Cocktail Bars, Nightlife, Restaurants, Mediterranean, Bars',
#  'Coffee & Tea, Breakfast & Brunch, Restaurants, Gluten-Free, Cafes, Food',
#  'Restaurants, Peruvian, Latin American',
#  'Restaurants, Seafood, Steakhouses, Chicken Shop, American (Traditional)',
#  'Sports Bars, American (Traditional), Seafood, American (New), Adult Entertainment, Nightlife, Burgers, Bars, Restaurants',
#  'Desserts, Food, Sandwiches, Cafes, Restaurants, Coffee & Tea, Breakfast & Brunch, Salad',
#  'Food Trucks, Food Delivery Services, Street Vendors, Desserts, Food Stands, Restaurants, Food, Cupcakes, Bakeries',
#  'Parks, Swimming Pools, Boating, Fishing, Active Life, Beaches',
#  'Restaurants, Food, Seafood Markets, Seafood, Specialty Food',
#  'Mediterranean, Restaurants',
#  'Seafood, Restaurants',
#  'Bakeries, Food',
#  'Active Life, Hiking',
#  'Nightlife, Bars, Comfort Food, Cocktail Bars, Restaurants, American (New), Breakfast & Brunch',
#  'Restaurants, Seafood, Bars, Salad, Tapas/Small Plates, Nightlife',
#  'Breakfast & Brunch, Bars, American (New), Nightlife, Wine Bars, Restaurants',
#  'Restaurants, American (Traditional)',
#  'Restaurants, Food, Chinese',
#  'New Mexican Cuisine, Mexican, Bars, Wine Bars, Nightlife, Restaurants',
#  'Food, Event Planning & Services, American (Traditional), Caterers, Smokehouse, Barbeque, Sandwiches, Restaurants',
#  'Active Life, Nightlife, Bars, American (Traditional), Bowling, Restaurants, American (New), Gastropubs',
#  'Korean, Restaurants, Soup, Asian Fusion, Barbeque, Sushi Bars, Nightlife, Cocktail Bars, Bars',
#  'Asian Fusion, Restaurants, Korean',
#  'Greek, Restaurants, Mediterranean, Middle Eastern, Turkish',
#  'Chicken Wings, Salad, Restaurants, Nightlife, Bars, Beer Bar, Pizza',
#  'French, American (New), Restaurants',
#  'Bowling, Nightlife, Karaoke, Arts & Entertainment, Active Life, Arcades',
#  'Restaurants, Buffets',
#  'Arts & Entertainment, Nightlife, Music Venues, Breweries, American (Traditional), Food, Restaurants',
#  'Restaurants, Buffets, Southern',
#  'Nightlife, Bars, Restaurants, Tex-Mex, Cocktail Bars, Tacos, Mexican',
#  'Shopping Centers, Outlet Stores, Restaurants, Fashion, Shopping',
#  'Restaurants, Sandwiches, Soup, Salad, Breakfast & Brunch',
#  'Seafood, Steakhouses, Brazilian, Restaurants',
#  'American (Traditional), Breakfast & Brunch, German, Gastropubs, Restaurants, American (New)',
#  'Desserts, Ice Cream & Frozen Yogurt, Gelato, Food',
#  'Champagne Bars, Bars, Nightlife, Lounges, Beer Bar, Cocktail Bars, Wine Bars, Pop-Up Restaurants, Restaurants, Salad',
#  'Automotive, Auto Repair, Auto Detailing, Auto Parts & Supplies, Car Wash',
#  'Event Planning & Services, Butcher, American (Traditional), American (New), Cooking Classes, Venues & Event Spaces, Arts & Crafts, Shopping, Restaurants, Food',
#  'Restaurants, Chinese',
#  'Breakfast & Brunch, Seafood, Sandwiches, Restaurants',
#  'Mediterranean, Restaurants, Greek',
#  'Cafes, Bars, American (New), Restaurants, Cocktail Bars, Nightlife, Lounges, Comfort Food',
#  'Nightlife, Event Planning & Services, Tours, Venues & Event Spaces, Music Venues, Hotels & Travel, Performing Arts, Arts & Entertainment',
#  'Mexican, Tacos, Restaurants',
#  'Restaurants, Event Planning & Services, Bars, Caterers, Venues & Event Spaces, Italian, Pizza, Wine Bars, Nightlife',
#  'American (New), Breweries, Desserts, American (Traditional), Restaurants, Food',
#  'Coffee & Tea, Food, Beer, Wine & Spirits, Restaurants, Breakfast & Brunch, Bakeries',
#  'Food, Hawaiian, Restaurants, Poke, Japanese',
#  'Specialty Food, Event Planning & Services, Food, Venues & Event Spaces, Real Estate, Restaurants, Southern, Food Court, Bars, Shared Office Spaces, Nightlife, Home Services',
#  'Restaurants, Pizza',
#  'Tex-Mex, Dive Bars, Bars, Beer, Wine & Spirits, American (New), Restaurants, Gastropubs, Nightlife, Southern, American (Traditional), Beer Bar, Food',
#  'Restaurants, Pizza, Italian',
#  'Arts & Entertainment, Pick Your Own Farms, Specialty Food, Fruits & Veggies, Farmers Market, Farms, Local Flavor, Food',
#  'Salad, Sandwiches, Restaurants, Delis',
#  'Breakfast & Brunch, Cafes, American (New), Pubs, Restaurants, Bars, Nightlife',
#  'Asian Fusion, Restaurants, Seafood, Diners, Sushi Bars',
#  'Comfort Food, Southern, Desserts, Food, Restaurants',
#  'Restaurants, Greek, Food, Desserts, Mediterranean, Salad',
#  'Breakfast & Brunch, Italian, Food, Restaurants, Desserts',
#  'Juice Bars & Smoothies, Food, Cafes, Restaurants, Acai Bowls',
#  'Sushi Bars, Food, Japanese, Poke, Restaurants',
#  'Fast Food, Restaurants, Southern, Chicken Shop, Chicken Wings, American (Traditional)',
#  'Breakfast & Brunch, Restaurants',
#  'Italian, Restaurants, Soup, Salad, Bars, Nightlife, Wine Bars',
#  'French, Arts & Entertainment, Cocktail Bars, American (Traditional), Brasseries, Bars, Beer Gardens, Music Venues, Restaurants, Gastropubs, Tapas/Small Plates, Nightlife, American (New)',
#  'American (Traditional), Greek, Restaurants, Breakfast & Brunch',
#  'Bars, Nightlife, Sandwiches, Restaurants, Arts & Entertainment, Music Venues',
#  'Restaurants, Food, Breakfast & Brunch, Coffee & Tea, Cafes',
#  'Bakeries, Restaurants, Cafes, Food, Coffee & Tea, Breakfast & Brunch',
#  'Breakfast & Brunch, Patisserie/Cake Shop, Coffee & Tea, Restaurants, French, Cafes, Food',
#  'Comfort Food, American (Traditional), Restaurants, Sandwiches, Breakfast & Brunch',
#  'Restaurants, Barbeque, Soul Food, Southern',
#  'Soul Food, Restaurants, Caribbean, Latin American',
#  'Community Service/Non-Profit, Arts & Entertainment, Local Services, Local Flavor, Art Galleries, Event Planning & Services, Venues & Event Spaces, Shopping',
#  'Caterers, Event Planning & Services, Delis, Restaurants, American (New), Food, Cafes, Desserts, Coffee & Tea',
#  'Latin American, Peruvian, Chicken Shop, Restaurants, Sandwiches',
#  'American (Traditional), Restaurants, Bars, Cocktail Bars, Nightlife',
#  'Cheesesteaks, Comfort Food, Restaurants, Delis, Burgers, American (Traditional), Sandwiches, Local Flavor',
#  'Restaurants, Bars, Irish, Nightlife, Sports Bars, American (Traditional)',
#  'Desserts, Restaurants, Salad, Breakfast & Brunch, Food',
#  'Bars, Nightlife, Restaurants, Wine Bars, Salad, Tapas/Small Plates, Cocktail Bars, American (New)',
#  'Tex-Mex, Restaurants, Food, Nightlife, Beer, Wine & Spirits, Pubs, Bars, Mexican',
#  'Restaurants, Chinese',
#  'Grocery, Farmers Market, Fruits & Veggies, Shopping, Food, Wholesale Stores, Specialty Food',
#  'Lounges, Bars, Seafood, Restaurants, Nightlife',
#  'Restaurants, Seafood',
#  'Event Planning & Services, Sports Bars, Arts & Entertainment, Venues & Event Spaces, Books, Mags, Music & Video, Amusement Parks, American (Traditional), Shopping, Restaurants, Videos & Video Game Rental, Active Life, Bars, Arcades, Nightlife',
#  'Nightlife, Bars, Food, Tacos, Restaurants, Desserts, New Mexican Cuisine, Breakfast & Brunch, Mexican, Tex-Mex',
#  'Soup, Restaurants, Vietnamese, Noodles',
#  'Bars, American (Traditional), Nightlife, Restaurants',
#  'Pizza, Restaurants, American (Traditional), Salad, Breakfast & Brunch',
#  'Food, Coffee & Tea, Restaurants',
#  'American (Traditional), Restaurants, Comfort Food, Southern',
#  'American (New), Restaurants, Sandwiches, Seafood, Cajun/Creole',
#  'Arts & Entertainment, Museums',
#  'Steakhouses, Restaurants, Seafood, American (Traditional)',
#  'Nightlife, Bars, Food, Ethnic Food, Middle Eastern, Vegetarian, Specialty Food, Israeli, Restaurants',
#  'Colombian, Latin American, Cuban, Restaurants',
#  'Restaurants, Lounges, Bars, Mexican, Nightlife, Tex-Mex, Breakfast & Brunch',
#  'Desserts, Comfort Food, Bars, Nightlife, Bakeries, Food, Restaurants, Breakfast & Brunch',
#  'French, Restaurants, Cocktail Bars, Nightlife, American (New), Cajun/Creole, Breakfast & Brunch, American (Traditional), Bars',
#  'Food, Irish Pub, Pubs, Music Venues, Bars, Arts & Entertainment, Beer, Wine & Spirits, Irish, Restaurants, Nightlife',
#  'American (Traditional), Barbeque, Restaurants, Caterers, Sandwiches, American (New), Food Delivery Services, Wedding Planning, Food, Event Planning & Services',
#  'Restaurants, Seafood, Nightlife, Sandwiches, American (New), Bars, French, Cocktail Bars',
#  'Mexican, Restaurants',
#  'Steakhouses, Bars, Nightlife, American (Traditional), Restaurants',
#  'Restaurants, Tacos, Bars, Nightlife, Mexican',
#  'Coffee & Tea, Juice Bars & Smoothies, Bakeries, Bagels, Food',
#  'Parks, Hiking, Active Life, Boating',
#  'Breakfast & Brunch, Pizza, Southern, Italian, Nightlife, Bars, Restaurants, American (Traditional)',
#  'Restaurants, Vietnamese',
#  'Comfort Food, American (Traditional), Southern, Restaurants',
#  'Karaoke, American (Traditional), Restaurants, Dive Bars, Bars, Nightlife',
#  'Pubs, Restaurants, Nightlife, Bars, British, Sandwiches, American (Traditional), Burgers',
#  'Restaurants, Food, Vegan, Cafes, Donuts',
#  'Nightlife, Breakfast & Brunch, Bars, American (New), Restaurants, American (Traditional)',
#  'Breweries, Bars, Nightlife, Barbeque, Restaurants, Food',
#  'Chocolatiers & Shops, Coffee & Tea, Food, Desserts, Specialty Food',
#  'Restaurants, Food, Hawaiian, Vegan, Sushi Bars, Poke',
#  'Vegan, Arts & Entertainment, Shopping, Restaurants, Vegetarian, Art Galleries, Food, Cafes, Bakeries, Desserts',
#  'Seafood, Food, Salad, Restaurants, Beer, Wine & Spirits, Soup, American (Traditional)',
#  'Food, Ice Cream & Frozen Yogurt',
#  'Coffee & Tea, Vegan, Restaurants, Breakfast & Brunch, Food',
#  'Car Rental, Hotels & Travel, Transportation, Airports',
#  'Nightlife, Beer Bar, Bars, Barbeque, Sandwiches, Restaurants, Seafood',
#  'Wine Bars, Bars, Seafood, Nightlife, Steakhouses, Restaurants, American (Traditional)',
#  'Restaurants, Burgers, American (Traditional), Breakfast & Brunch',
#  'Food, International Grocery, Grocery, Specialty Food',
#  'Indian, Restaurants, Himalayan/Nepalese',
#  'Food, Coffee & Tea, Restaurants, Bubble Tea, Taiwanese',
#  'Pizza, Restaurants',
#  'Pubs, Nightlife, American (Traditional), Barbeque, Restaurants, Bars',
#  'American (New), Sandwiches, Brewpubs, Nightlife, Beer, Wine & Spirits, Event Planning & Services, Breweries, German, Food, Local Flavor, Venues & Event Spaces, Restaurants',
#  'Breakfast & Brunch, Waffles, Restaurants',
#  'Hot Dogs, American (New), Barbeque, Burgers, Chicken Wings, Restaurants',
#  'Airport Lounges, Bars, Nightlife',
#  'Yelp Events, Local Flavor',
#  'Gelato, Food, Desserts, Ice Cream & Frozen Yogurt, Coffee & Tea',
#  'Chinese, Japanese, Asian Fusion, Sushi Bars, Restaurants',
#  'American (Traditional), Fast Food, Restaurants, Organic Stores, Food, Burgers, Salad',
#  'Food, Pubs, Bars, Breweries, Nightlife',
#  'Breakfast & Brunch, Restaurants, Beer Bar, Nightlife, Salad, Bars, Food, American (New), Cocktail Bars, Gastropubs',
#  'Pubs, Cuban, Bars, Restaurants, Nightlife, Food, Music Venues, Breweries, Arts & Entertainment',
#  'Breakfast & Brunch, Restaurants, Diners',
#  'Coffee & Tea, Food, Coffee Roasteries',
#  'Bars, Steakhouses, Restaurants, Event Planning & Services, Nightlife, Caterers, Pubs, Sandwiches, Seafood, Pizza',
#  'Sandwiches, Religious Organizations, Juice Bars & Smoothies, American (Traditional), Salad, Food, Restaurants, Fast Food, Chicken Shop',
#  'Event Planning & Services, American (New), Food, Beer, Wine & Spirits, Gluten-Free, Venues & Event Spaces, Burgers, Restaurants',
#  ...]

# %%
# map

# %%
# group_deltas_general1 = delta_ndcg_scores_by_group(test_data, base_df_general1, calibrated_df_general1, user_groups)
# group_deltas_general2 = delta_ndcg_scores_by_group(test_data, base_df_general2, calibrated_df_general2, user_groups)
# group_deltas_context1 = delta_ndcg_scores_by_group(test_data, base_df_context1, calibrated_df_context1, user_groups)
# group_deltas_context2 = delta_ndcg_scores_by_group(test_data, base_df_context2, calibrated_df_context2, user_groups)

# %%
item_data.nunique()
# Out:
# item_id:token              4510
# name:token_seq             4039
# lat:float                  4461
# lon:float                  4446
# category_name:token_seq    3955
# dtype: int64
